# %%
import json
import os
import pandas as pd
import matplotlib.pyplot as plt
from time import time
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import SMOTE
from sentence_transformers import SentenceTransformer
from imblearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("../PreProcessingResumes/processed_data/Resume/train.csv")
df.head()
# Out:
#          ID                                         Resume_str  \
# 0  28111403  president chief executive officer executive pr...
# 1  29908929  business development marketing summary busines...
# 2  15261348  chef and restaurant manager summary chef with ...
# 3  75435017  charge nurse professional summary objective to...
# 4  41152404  test analyst intern contractor profile years o...
#
#                  Category
# 0  INFORMATION-TECHNOLOGY
# 1    BUSINESS-DEVELOPMENT
# 2                    CHEF
# 3              HEALTHCARE
# 4  INFORMATION-TECHNOLOGY

# %%
# Convert resumes column to a list
resumes = df["Resume_str"].tolist()
    
# Encode category labels as integers
encoder = LabelEncoder()
labels = encoder.fit_transform(df["Category"])
category_names = encoder.classes_.tolist()

# %%
# Load the SBERT model for generating sentence embeddings
sbert_model = SentenceTransformer('all-MiniLM-L12-v2')

# %%
# Generate SBERT embeddings
resumes_embed = sbert_model.encode(resumes, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/63 [00:00<?, ?it/s]

# %% [markdown]
# ### Random Forest Classifier

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
class_counts = df['Category'].value_counts()
min_classes = class_counts[class_counts < 0.75*class_counts.mean()].index.tolist()

print(f"Applying SMOTE to classes: {min_classes}")

target_size = int(0.75*class_counts.max())
sampling_strategy = {i: target_size for i, cls in enumerate(min_classes)}
# Out:
# Applying SMOTE to classes: ['ADVOCATE', 'APPAREL', 'BPO', 'AGRICULTURE', 'ARTS', 'AUTOMOBILE']

# %%
pipeline = Pipeline(steps=[
    ('smote', SMOTE(sampling_strategy=sampling_strategy, random_state=42, k_neighbors=4)),
    ('clf', RandomForestClassifier(random_state=42, n_jobs=5))
])

# %%
param_grid = {
    'clf__n_estimators': [400, 700],
    'clf__max_features': ['sqrt', 'log2'],
    'clf__max_depth' : [5, 7, 8],
    'clf__criterion' : ['gini', 'entropy'],
    'clf__min_samples_split': [10],
    'clf__min_samples_leaf': [15]
}

scoring = ['accuracy', 'f1_weighted', 'precision_weighted', 'recall_weighted']

grid = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=skf,
    scoring= scoring,
    refit = False,
    return_train_score=True,
    n_jobs=-1
)

start = time()
grid_search = grid.fit(resumes_embed, labels)

print(f"GridSearchCV took {(time() - start):.2f} seconds for {len(grid_search.cv_results_['params'])} candidates parameter settings.")
# Out:
# GridSearchCV took 749.61 seconds for 24 candidates parameter settings.

# %%
# Convert the cross-validation results from GridSearchCV into a pandas DataFrame
results_df = pd.DataFrame(grid_search.cv_results_)

# Sort the results by the weighted F1 score in descending order
results_df = results_df.sort_values(by='mean_test_f1_weighted', ascending=False).reset_index(drop=True)

# %%
for i in range(len(results_df)):
    print(f"\n[{i+1}] Params: {results_df['params'][i]}")
    
    for metric in scoring:
        
        print(f"{metric.upper()}:")
        print(f"\tTRAIN:", end='')
        for fold in range(skf.get_n_splits()):
            print(f"\tFold {fold+1}: {results_df[f'split{fold}_train_{metric}'][i]:.4f}", end='')
        print(f"\t\tMean: {results_df[f'mean_train_{metric}'][i]:.4f}", end='')
        print(f"\tStd: {results_df[f'std_train_{metric}'][i]:.4f}")

        print(f"\tTEST:", end='')
        for fold in range(skf.get_n_splits()):
            print(f"\tFold {fold+1}: {results_df[f'split{fold}_test_{metric}'][i]:.4f}", end='')
        print(f"\t\tMean: {results_df[f'mean_test_{metric}'][i]:.4f}", end='')
        print(f"\tStd: {results_df[f'std_test_{metric}'][i]:.4f}\n")
# Out:
# [1] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 7, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9037	Fold 2: 0.9100	Fold 3: 0.9094	Fold 4: 0.9050	Fold 5: 0.9062		Mean: 0.9068	Std: 0.0025
# 	TEST:	Fold 1: 0.7387	Fold 2: 0.6826	Fold 3: 0.7053	Fold 4: 0.7053	Fold 5: 0.6927		Mean: 0.7049	Std: 0.0189
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8970	Fold 2: 0.9011	Fold 3: 0.9039	Fold 4: 0.8985	Fold 5: 0.9002		Mean: 0.9001	Std: 0.0024
# 	TEST:	Fold 1: 0.7287	Fold 2: 0.6684	Fold 3: 0.6870	Fold 4: 0.6933	Fold 5: 0.6770		Mean: 0.6909	Std: 0.0207
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9139	Fold 2: 0.9195	Fold 3: 0.9188	Fold 4: 0.9154	Fold 5: 0.9153		Mean: 0.9166	Std: 0.0022
# 	TEST:	Fold 1: 0.7604	Fold 2: 0.7325	Fold 3: 0.7364	Fold 4: 0.7389	Fold 5: 0.7174		Mean: 0.7371	Std: 0.0138
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9037	Fold 2: 0.9100	Fold 3: 0.9094	Fold 4: 0.9050	Fold 5: 0.9062		Mean: 0.9068	Std: 0.0025
# 	TEST:	Fold 1: 0.7387	Fold 2: 0.6826	Fold 3: 0.7053	Fold 4: 0.7053	Fold 5: 0.6927		Mean: 0.7049	Std: 0.0189
#
#
# [2] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 8, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9112	Fold 2: 0.9132	Fold 3: 0.9119	Fold 4: 0.9081	Fold 5: 0.9087		Mean: 0.9106	Std: 0.0019
# 	TEST:	Fold 1: 0.7412	Fold 2: 0.6751	Fold 3: 0.7128	Fold 4: 0.7053	Fold 5: 0.6851		Mean: 0.7039	Std: 0.0231
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9064	Fold 2: 0.9056	Fold 3: 0.9082	Fold 4: 0.9033	Fold 5: 0.9037		Mean: 0.9054	Std: 0.0018
# 	TEST:	Fold 1: 0.7299	Fold 2: 0.6602	Fold 3: 0.6967	Fold 4: 0.6930	Fold 5: 0.6708		Mean: 0.6901	Std: 0.0241
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9191	Fold 2: 0.9199	Fold 3: 0.9193	Fold 4: 0.9167	Fold 5: 0.9173		Mean: 0.9185	Std: 0.0012
# 	TEST:	Fold 1: 0.7547	Fold 2: 0.6922	Fold 3: 0.7290	Fold 4: 0.7242	Fold 5: 0.7007		Mean: 0.7202	Std: 0.0221
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9112	Fold 2: 0.9132	Fold 3: 0.9119	Fold 4: 0.9081	Fold 5: 0.9087		Mean: 0.9106	Std: 0.0019
# 	TEST:	Fold 1: 0.7412	Fold 2: 0.6751	Fold 3: 0.7128	Fold 4: 0.7053	Fold 5: 0.6851		Mean: 0.7039	Std: 0.0231
#
#
# [3] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 8, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9106	Fold 2: 0.9163	Fold 3: 0.9138	Fold 4: 0.9125	Fold 5: 0.9100		Mean: 0.9126	Std: 0.0023
# 	TEST:	Fold 1: 0.7437	Fold 2: 0.6776	Fold 3: 0.7028	Fold 4: 0.6927	Fold 5: 0.6952		Mean: 0.7024	Std: 0.0222
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9068	Fold 2: 0.9093	Fold 3: 0.9096	Fold 4: 0.9082	Fold 5: 0.9047		Mean: 0.9077	Std: 0.0018
# 	TEST:	Fold 1: 0.7330	Fold 2: 0.6639	Fold 3: 0.6844	Fold 4: 0.6785	Fold 5: 0.6848		Mean: 0.6889	Std: 0.0233
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9185	Fold 2: 0.9231	Fold 3: 0.9217	Fold 4: 0.9205	Fold 5: 0.9179		Mean: 0.9203	Std: 0.0019
# 	TEST:	Fold 1: 0.7582	Fold 2: 0.6956	Fold 3: 0.7215	Fold 4: 0.7103	Fold 5: 0.7188		Mean: 0.7209	Std: 0.0207
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9106	Fold 2: 0.9163	Fold 3: 0.9138	Fold 4: 0.9125	Fold 5: 0.9100		Mean: 0.9126	Std: 0.0023
# 	TEST:	Fold 1: 0.7437	Fold 2: 0.6776	Fold 3: 0.7028	Fold 4: 0.6927	Fold 5: 0.6952		Mean: 0.7024	Std: 0.0222
#
#
# [4] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 8, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9074	Fold 2: 0.9176	Fold 3: 0.9106	Fold 4: 0.9163	Fold 5: 0.9113		Mean: 0.9126	Std: 0.0038
# 	TEST:	Fold 1: 0.7437	Fold 2: 0.6851	Fold 3: 0.6902	Fold 4: 0.6977	Fold 5: 0.6977		Mean: 0.7029	Std: 0.0210
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9028	Fold 2: 0.9094	Fold 3: 0.9051	Fold 4: 0.9125	Fold 5: 0.9062		Mean: 0.9072	Std: 0.0034
# 	TEST:	Fold 1: 0.7332	Fold 2: 0.6720	Fold 3: 0.6724	Fold 4: 0.6801	Fold 5: 0.6863		Mean: 0.6888	Std: 0.0228
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9166	Fold 2: 0.9265	Fold 3: 0.9195	Fold 4: 0.9244	Fold 5: 0.9191		Mean: 0.9212	Std: 0.0036
# 	TEST:	Fold 1: 0.7591	Fold 2: 0.7353	Fold 3: 0.7131	Fold 4: 0.7333	Fold 5: 0.7195		Mean: 0.7321	Std: 0.0159
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9074	Fold 2: 0.9176	Fold 3: 0.9106	Fold 4: 0.9163	Fold 5: 0.9113		Mean: 0.9126	Std: 0.0038
# 	TEST:	Fold 1: 0.7437	Fold 2: 0.6851	Fold 3: 0.6902	Fold 4: 0.6977	Fold 5: 0.6977		Mean: 0.7029	Std: 0.0210
#
#
# [5] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 8, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9081	Fold 2: 0.9157	Fold 3: 0.9087	Fold 4: 0.9087	Fold 5: 0.9081		Mean: 0.9099	Std: 0.0029
# 	TEST:	Fold 1: 0.7412	Fold 2: 0.6877	Fold 3: 0.6902	Fold 4: 0.6977	Fold 5: 0.6927		Mean: 0.7019	Std: 0.0199
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9037	Fold 2: 0.9083	Fold 3: 0.9038	Fold 4: 0.9025	Fold 5: 0.9032		Mean: 0.9043	Std: 0.0021
# 	TEST:	Fold 1: 0.7306	Fold 2: 0.6729	Fold 3: 0.6713	Fold 4: 0.6822	Fold 5: 0.6791		Mean: 0.6872	Std: 0.0220
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9166	Fold 2: 0.9248	Fold 3: 0.9182	Fold 4: 0.9184	Fold 5: 0.9161		Mean: 0.9188	Std: 0.0031
# 	TEST:	Fold 1: 0.7586	Fold 2: 0.7323	Fold 3: 0.7152	Fold 4: 0.7286	Fold 5: 0.7114		Mean: 0.7292	Std: 0.0166
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9081	Fold 2: 0.9157	Fold 3: 0.9087	Fold 4: 0.9087	Fold 5: 0.9081		Mean: 0.9099	Std: 0.0029
# 	TEST:	Fold 1: 0.7412	Fold 2: 0.6877	Fold 3: 0.6902	Fold 4: 0.6977	Fold 5: 0.6927		Mean: 0.7019	Std: 0.0199
#
#
# [6] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 7, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9005	Fold 2: 0.9125	Fold 3: 0.9031	Fold 4: 0.9012	Fold 5: 0.9018		Mean: 0.9038	Std: 0.0044
# 	TEST:	Fold 1: 0.7286	Fold 2: 0.6776	Fold 3: 0.7003	Fold 4: 0.7103	Fold 5: 0.6826		Mean: 0.6999	Std: 0.0186
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8949	Fold 2: 0.9060	Fold 3: 0.8970	Fold 4: 0.8955	Fold 5: 0.8945		Mean: 0.8976	Std: 0.0043
# 	TEST:	Fold 1: 0.7159	Fold 2: 0.6622	Fold 3: 0.6853	Fold 4: 0.6989	Fold 5: 0.6715		Mean: 0.6867	Std: 0.0191
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9111	Fold 2: 0.9209	Fold 3: 0.9117	Fold 4: 0.9106	Fold 5: 0.9106		Mean: 0.9130	Std: 0.0040
# 	TEST:	Fold 1: 0.7383	Fold 2: 0.7080	Fold 3: 0.7224	Fold 4: 0.7425	Fold 5: 0.7112		Mean: 0.7245	Std: 0.0139
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9005	Fold 2: 0.9125	Fold 3: 0.9031	Fold 4: 0.9012	Fold 5: 0.9018		Mean: 0.9038	Std: 0.0044
# 	TEST:	Fold 1: 0.7286	Fold 2: 0.6776	Fold 3: 0.7003	Fold 4: 0.7103	Fold 5: 0.6826		Mean: 0.6999	Std: 0.0186
#
#
# [7] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 7, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9011	Fold 2: 0.9094	Fold 3: 0.9069	Fold 4: 0.9025	Fold 5: 0.9025		Mean: 0.9045	Std: 0.0031
# 	TEST:	Fold 1: 0.7387	Fold 2: 0.6826	Fold 3: 0.7003	Fold 4: 0.6927	Fold 5: 0.6952		Mean: 0.7019	Std: 0.0193
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8946	Fold 2: 0.9010	Fold 3: 0.9011	Fold 4: 0.8955	Fold 5: 0.8955		Mean: 0.8976	Std: 0.0029
# 	TEST:	Fold 1: 0.7267	Fold 2: 0.6679	Fold 3: 0.6827	Fold 4: 0.6744	Fold 5: 0.6799		Mean: 0.6863	Std: 0.0208
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9113	Fold 2: 0.9198	Fold 3: 0.9165	Fold 4: 0.9140	Fold 5: 0.9114		Mean: 0.9146	Std: 0.0032
# 	TEST:	Fold 1: 0.7546	Fold 2: 0.7238	Fold 3: 0.7304	Fold 4: 0.7105	Fold 5: 0.7192		Mean: 0.7277	Std: 0.0149
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9011	Fold 2: 0.9094	Fold 3: 0.9069	Fold 4: 0.9025	Fold 5: 0.9025		Mean: 0.9045	Std: 0.0031
# 	TEST:	Fold 1: 0.7387	Fold 2: 0.6826	Fold 3: 0.7003	Fold 4: 0.6927	Fold 5: 0.6952		Mean: 0.7019	Std: 0.0193
#
#
# [8] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 7, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8999	Fold 2: 0.9138	Fold 3: 0.9094	Fold 4: 0.9037	Fold 5: 0.9031		Mean: 0.9060	Std: 0.0050
# 	TEST:	Fold 1: 0.7286	Fold 2: 0.6776	Fold 3: 0.6977	Fold 4: 0.7003	Fold 5: 0.6851		Mean: 0.6979	Std: 0.0175
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8928	Fold 2: 0.9063	Fold 3: 0.9052	Fold 4: 0.8983	Fold 5: 0.8967		Mean: 0.8999	Std: 0.0052
# 	TEST:	Fold 1: 0.7167	Fold 2: 0.6644	Fold 3: 0.6822	Fold 4: 0.6875	Fold 5: 0.6742		Mean: 0.6850	Std: 0.0177
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9095	Fold 2: 0.9215	Fold 3: 0.9174	Fold 4: 0.9132	Fold 5: 0.9124		Mean: 0.9148	Std: 0.0042
# 	TEST:	Fold 1: 0.7396	Fold 2: 0.7101	Fold 3: 0.7215	Fold 4: 0.7317	Fold 5: 0.7142		Mean: 0.7234	Std: 0.0109
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8999	Fold 2: 0.9138	Fold 3: 0.9094	Fold 4: 0.9037	Fold 5: 0.9031		Mean: 0.9060	Std: 0.0050
# 	TEST:	Fold 1: 0.7286	Fold 2: 0.6776	Fold 3: 0.6977	Fold 4: 0.7003	Fold 5: 0.6851		Mean: 0.6979	Std: 0.0175
#
#
# [9] Params: {'clf__criterion': 'gini', 'clf__max_depth': 8, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8715	Fold 2: 0.8848	Fold 3: 0.8729	Fold 4: 0.8722	Fold 5: 0.8678		Mean: 0.8739	Std: 0.0058
# 	TEST:	Fold 1: 0.7312	Fold 2: 0.6776	Fold 3: 0.6977	Fold 4: 0.6977	Fold 5: 0.6751		Mean: 0.6959	Std: 0.0201
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8617	Fold 2: 0.8746	Fold 3: 0.8630	Fold 4: 0.8623	Fold 5: 0.8572		Mean: 0.8637	Std: 0.0058
# 	TEST:	Fold 1: 0.7183	Fold 2: 0.6619	Fold 3: 0.6794	Fold 4: 0.6758	Fold 5: 0.6608		Mean: 0.6792	Std: 0.0209
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8681	Fold 2: 0.8796	Fold 3: 0.8698	Fold 4: 0.8685	Fold 5: 0.8645		Mean: 0.8701	Std: 0.0051
# 	TEST:	Fold 1: 0.7555	Fold 2: 0.7273	Fold 3: 0.7235	Fold 4: 0.7461	Fold 5: 0.7172		Mean: 0.7339	Std: 0.0145
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8715	Fold 2: 0.8848	Fold 3: 0.8729	Fold 4: 0.8722	Fold 5: 0.8678		Mean: 0.8739	Std: 0.0058
# 	TEST:	Fold 1: 0.7312	Fold 2: 0.6776	Fold 3: 0.6977	Fold 4: 0.6977	Fold 5: 0.6751		Mean: 0.6959	Std: 0.0201
#
#
# [10] Params: {'clf__criterion': 'gini', 'clf__max_depth': 8, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8753	Fold 2: 0.8848	Fold 3: 0.8741	Fold 4: 0.8741	Fold 5: 0.8697		Mean: 0.8756	Std: 0.0050
# 	TEST:	Fold 1: 0.7236	Fold 2: 0.6700	Fold 3: 0.6851	Fold 4: 0.7078	Fold 5: 0.6801		Mean: 0.6933	Std: 0.0196
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8652	Fold 2: 0.8744	Fold 3: 0.8642	Fold 4: 0.8644	Fold 5: 0.8589		Mean: 0.8654	Std: 0.0050
# 	TEST:	Fold 1: 0.7099	Fold 2: 0.6520	Fold 3: 0.6639	Fold 4: 0.6881	Fold 5: 0.6661		Mean: 0.6760	Std: 0.0206
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8709	Fold 2: 0.8794	Fold 3: 0.8710	Fold 4: 0.8698	Fold 5: 0.8653		Mean: 0.8713	Std: 0.0046
# 	TEST:	Fold 1: 0.7479	Fold 2: 0.7263	Fold 3: 0.7147	Fold 4: 0.7457	Fold 5: 0.7194		Mean: 0.7308	Std: 0.0136
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8753	Fold 2: 0.8848	Fold 3: 0.8741	Fold 4: 0.8741	Fold 5: 0.8697		Mean: 0.8756	Std: 0.0050
# 	TEST:	Fold 1: 0.7236	Fold 2: 0.6700	Fold 3: 0.6851	Fold 4: 0.7078	Fold 5: 0.6801		Mean: 0.6933	Std: 0.0196
#
#
# [11] Params: {'clf__criterion': 'gini', 'clf__max_depth': 8, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8589	Fold 2: 0.8697	Fold 3: 0.8634	Fold 4: 0.8540	Fold 5: 0.8597		Mean: 0.8612	Std: 0.0052
# 	TEST:	Fold 1: 0.7085	Fold 2: 0.6751	Fold 3: 0.6902	Fold 4: 0.6902	Fold 5: 0.6574		Mean: 0.6843	Std: 0.0171
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8480	Fold 2: 0.8590	Fold 3: 0.8528	Fold 4: 0.8431	Fold 5: 0.8487		Mean: 0.8503	Std: 0.0053
# 	TEST:	Fold 1: 0.6933	Fold 2: 0.6603	Fold 3: 0.6697	Fold 4: 0.6761	Fold 5: 0.6437		Mean: 0.6686	Std: 0.0165
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8550	Fold 2: 0.8647	Fold 3: 0.8595	Fold 4: 0.8540	Fold 5: 0.8568		Mean: 0.8580	Std: 0.0038
# 	TEST:	Fold 1: 0.7281	Fold 2: 0.7180	Fold 3: 0.7310	Fold 4: 0.7254	Fold 5: 0.7071		Mean: 0.7219	Std: 0.0086
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8589	Fold 2: 0.8697	Fold 3: 0.8634	Fold 4: 0.8540	Fold 5: 0.8597		Mean: 0.8612	Std: 0.0052
# 	TEST:	Fold 1: 0.7085	Fold 2: 0.6751	Fold 3: 0.6902	Fold 4: 0.6902	Fold 5: 0.6574		Mean: 0.6843	Std: 0.0171
#
#
# [12] Params: {'clf__criterion': 'gini', 'clf__max_depth': 8, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8621	Fold 2: 0.8685	Fold 3: 0.8660	Fold 4: 0.8521	Fold 5: 0.8534		Mean: 0.8604	Std: 0.0066
# 	TEST:	Fold 1: 0.7111	Fold 2: 0.6826	Fold 3: 0.7053	Fold 4: 0.6776	Fold 5: 0.6499		Mean: 0.6853	Std: 0.0218
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8513	Fold 2: 0.8580	Fold 3: 0.8556	Fold 4: 0.8414	Fold 5: 0.8421		Mean: 0.8497	Std: 0.0068
# 	TEST:	Fold 1: 0.6960	Fold 2: 0.6701	Fold 3: 0.6847	Fold 4: 0.6556	Fold 5: 0.6345		Mean: 0.6682	Std: 0.0216
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8582	Fold 2: 0.8642	Fold 3: 0.8626	Fold 4: 0.8525	Fold 5: 0.8515		Mean: 0.8578	Std: 0.0051
# 	TEST:	Fold 1: 0.7383	Fold 2: 0.7264	Fold 3: 0.7369	Fold 4: 0.7297	Fold 5: 0.6984		Mean: 0.7260	Std: 0.0145
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8621	Fold 2: 0.8685	Fold 3: 0.8660	Fold 4: 0.8521	Fold 5: 0.8534		Mean: 0.8604	Std: 0.0066
# 	TEST:	Fold 1: 0.7111	Fold 2: 0.6826	Fold 3: 0.7053	Fold 4: 0.6776	Fold 5: 0.6499		Mean: 0.6853	Std: 0.0218
#
#
# [13] Params: {'clf__criterion': 'gini', 'clf__max_depth': 7, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8514	Fold 2: 0.8578	Fold 3: 0.8559	Fold 4: 0.8521	Fold 5: 0.8471		Mean: 0.8528	Std: 0.0037
# 	TEST:	Fold 1: 0.7136	Fold 2: 0.6448	Fold 3: 0.6751	Fold 4: 0.6877	Fold 5: 0.6650		Mean: 0.6772	Std: 0.0229
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8405	Fold 2: 0.8446	Fold 3: 0.8446	Fold 4: 0.8410	Fold 5: 0.8355		Mean: 0.8412	Std: 0.0033
# 	TEST:	Fold 1: 0.6954	Fold 2: 0.6247	Fold 3: 0.6475	Fold 4: 0.6630	Fold 5: 0.6478		Mean: 0.6557	Std: 0.0233
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8527	Fold 2: 0.8591	Fold 3: 0.8571	Fold 4: 0.8537	Fold 5: 0.8495		Mean: 0.8544	Std: 0.0034
# 	TEST:	Fold 1: 0.7468	Fold 2: 0.7134	Fold 3: 0.7096	Fold 4: 0.7381	Fold 5: 0.7182		Mean: 0.7252	Std: 0.0146
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8514	Fold 2: 0.8578	Fold 3: 0.8559	Fold 4: 0.8521	Fold 5: 0.8471		Mean: 0.8528	Std: 0.0037
# 	TEST:	Fold 1: 0.7136	Fold 2: 0.6448	Fold 3: 0.6751	Fold 4: 0.6877	Fold 5: 0.6650		Mean: 0.6772	Std: 0.0229
#
#
# [14] Params: {'clf__criterion': 'gini', 'clf__max_depth': 7, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8520	Fold 2: 0.8565	Fold 3: 0.8521	Fold 4: 0.8496	Fold 5: 0.8508		Mean: 0.8522	Std: 0.0023
# 	TEST:	Fold 1: 0.7236	Fold 2: 0.6398	Fold 3: 0.6776	Fold 4: 0.6801	Fold 5: 0.6599		Mean: 0.6762	Std: 0.0278
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8412	Fold 2: 0.8439	Fold 3: 0.8408	Fold 4: 0.8386	Fold 5: 0.8394		Mean: 0.8408	Std: 0.0018
# 	TEST:	Fold 1: 0.7117	Fold 2: 0.6210	Fold 3: 0.6524	Fold 4: 0.6534	Fold 5: 0.6396		Mean: 0.6556	Std: 0.0304
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8533	Fold 2: 0.8556	Fold 3: 0.8537	Fold 4: 0.8526	Fold 5: 0.8522		Mean: 0.8535	Std: 0.0012
# 	TEST:	Fold 1: 0.7528	Fold 2: 0.7156	Fold 3: 0.7125	Fold 4: 0.7311	Fold 5: 0.7117		Mean: 0.7247	Std: 0.0157
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8520	Fold 2: 0.8565	Fold 3: 0.8521	Fold 4: 0.8496	Fold 5: 0.8508		Mean: 0.8522	Std: 0.0023
# 	TEST:	Fold 1: 0.7236	Fold 2: 0.6398	Fold 3: 0.6776	Fold 4: 0.6801	Fold 5: 0.6599		Mean: 0.6762	Std: 0.0278
#
#
# [15] Params: {'clf__criterion': 'gini', 'clf__max_depth': 7, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8325	Fold 2: 0.8376	Fold 3: 0.8389	Fold 4: 0.8219	Fold 5: 0.8238		Mean: 0.8309	Std: 0.0070
# 	TEST:	Fold 1: 0.6834	Fold 2: 0.6524	Fold 3: 0.6675	Fold 4: 0.6725	Fold 5: 0.6373		Mean: 0.6626	Std: 0.0161
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8201	Fold 2: 0.8230	Fold 3: 0.8279	Fold 4: 0.8090	Fold 5: 0.8124		Mean: 0.8185	Std: 0.0069
# 	TEST:	Fold 1: 0.6610	Fold 2: 0.6323	Fold 3: 0.6421	Fold 4: 0.6493	Fold 5: 0.6173		Mean: 0.6404	Std: 0.0149
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8379	Fold 2: 0.8397	Fold 3: 0.8442	Fold 4: 0.8307	Fold 5: 0.8298		Mean: 0.8365	Std: 0.0055
# 	TEST:	Fold 1: 0.7264	Fold 2: 0.7037	Fold 3: 0.7235	Fold 4: 0.7264	Fold 5: 0.7037		Mean: 0.7168	Std: 0.0107
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8325	Fold 2: 0.8376	Fold 3: 0.8389	Fold 4: 0.8219	Fold 5: 0.8238		Mean: 0.8309	Std: 0.0070
# 	TEST:	Fold 1: 0.6834	Fold 2: 0.6524	Fold 3: 0.6675	Fold 4: 0.6725	Fold 5: 0.6373		Mean: 0.6626	Std: 0.0161
#
#
# [16] Params: {'clf__criterion': 'gini', 'clf__max_depth': 7, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8331	Fold 2: 0.8427	Fold 3: 0.8452	Fold 4: 0.8232	Fold 5: 0.8244		Mean: 0.8337	Std: 0.0091
# 	TEST:	Fold 1: 0.6859	Fold 2: 0.6650	Fold 3: 0.6675	Fold 4: 0.6650	Fold 5: 0.6373		Mean: 0.6641	Std: 0.0156
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8205	Fold 2: 0.8295	Fold 3: 0.8344	Fold 4: 0.8109	Fold 5: 0.8118		Mean: 0.8214	Std: 0.0094
# 	TEST:	Fold 1: 0.6657	Fold 2: 0.6443	Fold 3: 0.6383	Fold 4: 0.6376	Fold 5: 0.6160		Mean: 0.6404	Std: 0.0159
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8375	Fold 2: 0.8454	Fold 3: 0.8489	Fold 4: 0.8319	Fold 5: 0.8297		Mean: 0.8387	Std: 0.0075
# 	TEST:	Fold 1: 0.7236	Fold 2: 0.7156	Fold 3: 0.6761	Fold 4: 0.7163	Fold 5: 0.7050		Mean: 0.7073	Std: 0.0167
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8331	Fold 2: 0.8427	Fold 3: 0.8452	Fold 4: 0.8232	Fold 5: 0.8244		Mean: 0.8337	Std: 0.0091
# 	TEST:	Fold 1: 0.6859	Fold 2: 0.6650	Fold 3: 0.6675	Fold 4: 0.6650	Fold 5: 0.6373		Mean: 0.6641	Std: 0.0156
#
#
# [17] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 5, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8098	Fold 2: 0.8219	Fold 3: 0.8232	Fold 4: 0.8175	Fold 5: 0.8238		Mean: 0.8192	Std: 0.0052
# 	TEST:	Fold 1: 0.7035	Fold 2: 0.6448	Fold 3: 0.6474	Fold 4: 0.6599	Fold 5: 0.6474		Mean: 0.6606	Std: 0.0221
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.7976	Fold 2: 0.8071	Fold 3: 0.8103	Fold 4: 0.8046	Fold 5: 0.8108		Mean: 0.8061	Std: 0.0048
# 	TEST:	Fold 1: 0.6868	Fold 2: 0.6202	Fold 3: 0.6198	Fold 4: 0.6380	Fold 5: 0.6209		Mean: 0.6372	Std: 0.0258
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8245	Fold 2: 0.8348	Fold 3: 0.8344	Fold 4: 0.8299	Fold 5: 0.8351		Mean: 0.8317	Std: 0.0041
# 	TEST:	Fold 1: 0.7569	Fold 2: 0.7069	Fold 3: 0.6996	Fold 4: 0.7195	Fold 5: 0.7049		Mean: 0.7175	Std: 0.0207
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8098	Fold 2: 0.8219	Fold 3: 0.8232	Fold 4: 0.8175	Fold 5: 0.8238		Mean: 0.8192	Std: 0.0052
# 	TEST:	Fold 1: 0.7035	Fold 2: 0.6448	Fold 3: 0.6474	Fold 4: 0.6599	Fold 5: 0.6474		Mean: 0.6606	Std: 0.0221
#
#
# [18] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 5, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8086	Fold 2: 0.8276	Fold 3: 0.8188	Fold 4: 0.8150	Fold 5: 0.8125		Mean: 0.8165	Std: 0.0065
# 	TEST:	Fold 1: 0.7060	Fold 2: 0.6322	Fold 3: 0.6700	Fold 4: 0.6549	Fold 5: 0.6297		Mean: 0.6586	Std: 0.0280
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.7950	Fold 2: 0.8137	Fold 3: 0.8070	Fold 4: 0.8037	Fold 5: 0.7997		Mean: 0.8038	Std: 0.0064
# 	TEST:	Fold 1: 0.6920	Fold 2: 0.6094	Fold 3: 0.6465	Fold 4: 0.6253	Fold 5: 0.6053		Mean: 0.6357	Std: 0.0316
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8203	Fold 2: 0.8347	Fold 3: 0.8299	Fold 4: 0.8291	Fold 5: 0.8250		Mean: 0.8278	Std: 0.0048
# 	TEST:	Fold 1: 0.7514	Fold 2: 0.6998	Fold 3: 0.7106	Fold 4: 0.6834	Fold 5: 0.6931		Mean: 0.7077	Std: 0.0236
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8086	Fold 2: 0.8276	Fold 3: 0.8188	Fold 4: 0.8150	Fold 5: 0.8125		Mean: 0.8165	Std: 0.0065
# 	TEST:	Fold 1: 0.7060	Fold 2: 0.6322	Fold 3: 0.6700	Fold 4: 0.6549	Fold 5: 0.6297		Mean: 0.6586	Std: 0.0280
#
#
# [19] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 5, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8042	Fold 2: 0.8156	Fold 3: 0.8118	Fold 4: 0.8137	Fold 5: 0.8169		Mean: 0.8124	Std: 0.0045
# 	TEST:	Fold 1: 0.6935	Fold 2: 0.6348	Fold 3: 0.6675	Fold 4: 0.6524	Fold 5: 0.6297		Mean: 0.6556	Std: 0.0232
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.7915	Fold 2: 0.8004	Fold 3: 0.7999	Fold 4: 0.8022	Fold 5: 0.8034		Mean: 0.7995	Std: 0.0042
# 	TEST:	Fold 1: 0.6786	Fold 2: 0.6138	Fold 3: 0.6443	Fold 4: 0.6227	Fold 5: 0.6040		Mean: 0.6327	Std: 0.0266
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8178	Fold 2: 0.8242	Fold 3: 0.8230	Fold 4: 0.8265	Fold 5: 0.8275		Mean: 0.8238	Std: 0.0034
# 	TEST:	Fold 1: 0.7539	Fold 2: 0.7063	Fold 3: 0.7145	Fold 4: 0.6427	Fold 5: 0.6597		Mean: 0.6954	Std: 0.0399
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8042	Fold 2: 0.8156	Fold 3: 0.8118	Fold 4: 0.8137	Fold 5: 0.8169		Mean: 0.8124	Std: 0.0045
# 	TEST:	Fold 1: 0.6935	Fold 2: 0.6348	Fold 3: 0.6675	Fold 4: 0.6524	Fold 5: 0.6297		Mean: 0.6556	Std: 0.0232
#
#
# [20] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 5, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8060	Fold 2: 0.8238	Fold 3: 0.8213	Fold 4: 0.8162	Fold 5: 0.8150		Mean: 0.8165	Std: 0.0061
# 	TEST:	Fold 1: 0.6910	Fold 2: 0.6373	Fold 3: 0.6524	Fold 4: 0.6448	Fold 5: 0.6348		Mean: 0.6520	Std: 0.0204
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.7935	Fold 2: 0.8090	Fold 3: 0.8079	Fold 4: 0.8043	Fold 5: 0.8018		Mean: 0.8033	Std: 0.0055
# 	TEST:	Fold 1: 0.6719	Fold 2: 0.6095	Fold 3: 0.6275	Fold 4: 0.6164	Fold 5: 0.6092		Mean: 0.6269	Std: 0.0235
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8225	Fold 2: 0.8352	Fold 3: 0.8324	Fold 4: 0.8331	Fold 5: 0.8274		Mean: 0.8301	Std: 0.0046
# 	TEST:	Fold 1: 0.7499	Fold 2: 0.6685	Fold 3: 0.7015	Fold 4: 0.6730	Fold 5: 0.6634		Mean: 0.6913	Std: 0.0322
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8060	Fold 2: 0.8238	Fold 3: 0.8213	Fold 4: 0.8162	Fold 5: 0.8150		Mean: 0.8165	Std: 0.0061
# 	TEST:	Fold 1: 0.6910	Fold 2: 0.6373	Fold 3: 0.6524	Fold 4: 0.6448	Fold 5: 0.6348		Mean: 0.6520	Std: 0.0204
#
#
# [21] Params: {'clf__criterion': 'gini', 'clf__max_depth': 5, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.7475	Fold 2: 0.7577	Fold 3: 0.7470	Fold 4: 0.7495	Fold 5: 0.7445		Mean: 0.7492	Std: 0.0045
# 	TEST:	Fold 1: 0.6633	Fold 2: 0.6020	Fold 3: 0.6373	Fold 4: 0.6322	Fold 5: 0.5894		Mean: 0.6249	Std: 0.0263
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.7261	Fold 2: 0.7252	Fold 3: 0.7228	Fold 4: 0.7212	Fold 5: 0.7154		Mean: 0.7222	Std: 0.0038
# 	TEST:	Fold 1: 0.6357	Fold 2: 0.5682	Fold 3: 0.5912	Fold 4: 0.6004	Fold 5: 0.5484		Mean: 0.5888	Std: 0.0297
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.7889	Fold 2: 0.7994	Fold 3: 0.7916	Fold 4: 0.7945	Fold 5: 0.7910		Mean: 0.7931	Std: 0.0036
# 	TEST:	Fold 1: 0.7054	Fold 2: 0.6410	Fold 3: 0.6010	Fold 4: 0.6582	Fold 5: 0.5887		Mean: 0.6388	Std: 0.0419
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.7475	Fold 2: 0.7577	Fold 3: 0.7470	Fold 4: 0.7495	Fold 5: 0.7445		Mean: 0.7492	Std: 0.0045
# 	TEST:	Fold 1: 0.6633	Fold 2: 0.6020	Fold 3: 0.6373	Fold 4: 0.6322	Fold 5: 0.5894		Mean: 0.6249	Std: 0.0263
#
#
# [22] Params: {'clf__criterion': 'gini', 'clf__max_depth': 5, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.7557	Fold 2: 0.7577	Fold 3: 0.7502	Fold 4: 0.7483	Fold 5: 0.7483		Mean: 0.7520	Std: 0.0039
# 	TEST:	Fold 1: 0.6658	Fold 2: 0.5995	Fold 3: 0.6297	Fold 4: 0.6373	Fold 5: 0.5970		Mean: 0.6259	Std: 0.0256
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.7334	Fold 2: 0.7268	Fold 3: 0.7233	Fold 4: 0.7202	Fold 5: 0.7195		Mean: 0.7246	Std: 0.0051
# 	TEST:	Fold 1: 0.6320	Fold 2: 0.5636	Fold 3: 0.5858	Fold 4: 0.6031	Fold 5: 0.5525		Mean: 0.5874	Std: 0.0284
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.7954	Fold 2: 0.8004	Fold 3: 0.7933	Fold 4: 0.7923	Fold 5: 0.7919		Mean: 0.7947	Std: 0.0031
# 	TEST:	Fold 1: 0.6662	Fold 2: 0.6376	Fold 3: 0.6125	Fold 4: 0.6662	Fold 5: 0.5882		Mean: 0.6342	Std: 0.0305
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.7557	Fold 2: 0.7577	Fold 3: 0.7502	Fold 4: 0.7483	Fold 5: 0.7483		Mean: 0.7520	Std: 0.0039
# 	TEST:	Fold 1: 0.6658	Fold 2: 0.5995	Fold 3: 0.6297	Fold 4: 0.6373	Fold 5: 0.5970		Mean: 0.6259	Std: 0.0256
#
#
# [23] Params: {'clf__criterion': 'gini', 'clf__max_depth': 5, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.7166	Fold 2: 0.7344	Fold 3: 0.7351	Fold 4: 0.7137	Fold 5: 0.7162		Mean: 0.7232	Std: 0.0095
# 	TEST:	Fold 1: 0.6332	Fold 2: 0.5970	Fold 3: 0.6222	Fold 4: 0.6196	Fold 5: 0.5894		Mean: 0.6123	Std: 0.0164
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.6835	Fold 2: 0.6935	Fold 3: 0.7062	Fold 4: 0.6777	Fold 5: 0.6791		Mean: 0.6880	Std: 0.0106
# 	TEST:	Fold 1: 0.5878	Fold 2: 0.5549	Fold 3: 0.5738	Fold 4: 0.5768	Fold 5: 0.5501		Mean: 0.5687	Std: 0.0141
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.7758	Fold 2: 0.7519	Fold 3: 0.7833	Fold 4: 0.7741	Fold 5: 0.7414		Mean: 0.7653	Std: 0.0159
# 	TEST:	Fold 1: 0.6226	Fold 2: 0.5968	Fold 3: 0.5933	Fold 4: 0.6292	Fold 5: 0.6054		Mean: 0.6094	Std: 0.0141
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.7166	Fold 2: 0.7344	Fold 3: 0.7351	Fold 4: 0.7137	Fold 5: 0.7162		Mean: 0.7232	Std: 0.0095
# 	TEST:	Fold 1: 0.6332	Fold 2: 0.5970	Fold 3: 0.6222	Fold 4: 0.6196	Fold 5: 0.5894		Mean: 0.6123	Std: 0.0164
#
#
# [24] Params: {'clf__criterion': 'gini', 'clf__max_depth': 5, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.7160	Fold 2: 0.7369	Fold 3: 0.7325	Fold 4: 0.7143	Fold 5: 0.7105		Mean: 0.7221	Std: 0.0106
# 	TEST:	Fold 1: 0.6357	Fold 2: 0.5844	Fold 3: 0.6146	Fold 4: 0.6121	Fold 5: 0.5844		Mean: 0.6062	Std: 0.0196
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.6821	Fold 2: 0.6975	Fold 3: 0.7034	Fold 4: 0.6762	Fold 5: 0.6711		Mean: 0.6860	Std: 0.0124
# 	TEST:	Fold 1: 0.5927	Fold 2: 0.5420	Fold 3: 0.5661	Fold 4: 0.5672	Fold 5: 0.5421		Mean: 0.5620	Std: 0.0189
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.7745	Fold 2: 0.7884	Fold 3: 0.7824	Fold 4: 0.7727	Fold 5: 0.7374		Mean: 0.7711	Std: 0.0178
# 	TEST:	Fold 1: 0.6615	Fold 2: 0.5751	Fold 3: 0.5872	Fold 4: 0.5920	Fold 5: 0.5545		Mean: 0.5941	Std: 0.0361
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.7160	Fold 2: 0.7369	Fold 3: 0.7325	Fold 4: 0.7143	Fold 5: 0.7105		Mean: 0.7221	Std: 0.0106
# 	TEST:	Fold 1: 0.6357	Fold 2: 0.5844	Fold 3: 0.6146	Fold 4: 0.6121	Fold 5: 0.5844		Mean: 0.6062	Std: 0.0196

# %%
for metric in scoring:
    data_test = {}
    data_train = {}
    for i in range(len(results_df)):
        col_name = f'{i+1}'
        data_test[col_name] = [results_df[f'split{fold}_test_{metric}'][i] for fold in range(skf.get_n_splits())]
        data_train[col_name] = [results_df[f'split{fold}_train_{metric}'][i] for fold in range(skf.get_n_splits())]

    df_test = pd.DataFrame(data_test)
    df_train = pd.DataFrame(data_train)

    means_test = df_test.mean()
    stds_test = df_test.std()
    means_train = df_train.mean()
    stds_train = df_train.std()

    plt.figure(figsize=(max(6, len(results_df) * 0.75), 4))

    plt.errorbar(means_test.index, means_test.values, yerr=stds_test.values, fmt='-o', capsize=5, label='Test', color='blue')

    plt.errorbar(means_train.index, means_train.values, yerr=stds_train.values, fmt='--s', capsize=5, label='Train', color='orange')

    plt.ylabel(f'{metric} score')
    plt.xlabel('Combination of parameters')
    plt.title(f'Model comparison on {metric} (mean ± std)')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
for metric in scoring:
    data = {}
    for i in range(len(results_df)):
        col_name = f'{i+1}'
        data[col_name] = [results_df[f'split{fold}_test_{metric}'][i] for fold in range(skf.get_n_splits())]

    df_metric = pd.DataFrame(data)
    ax = df_metric.boxplot(figsize=(max(6, len(results_df) * 0.75), 4))
    ax.set_ylabel(f'{metric} score')
    ax.set_xlabel('Combination of parameters')
    plt.title(f'Model comparison on {metric}')
    plt.grid(True)
    plt.show()

# %%
output_file = "compare/results.json"
section_key = "SBERT"

# Only process the first row
i = 0
entry = {
    "params": results_df['params'][i],
    "metrics": {}
}

for metric in scoring:
    train_folds = [results_df[f'split{fold}_train_{metric}'][i] for fold in range(skf.get_n_splits())]
    test_folds = [results_df[f'split{fold}_test_{metric}'][i] for fold in range(skf.get_n_splits())]

    entry["metrics"][metric] = {
        "train": {
            "folds": train_folds,
            "mean": results_df[f'mean_train_{metric}'][i],
            "std": results_df[f'std_train_{metric}'][i]
        },
        "test": {
            "folds": test_folds,
            "mean": results_df[f'mean_test_{metric}'][i],
            "std": results_df[f'std_test_{metric}'][i]
        }
    }

# Load or initialize the JSON structure
if os.path.exists(output_file):
    with open(output_file, 'r') as f:
        data = json.load(f)
else:
    data = {}

data[section_key] = entry

# Write the full updated JSON back to file
with open(output_file, 'w') as f:
    json.dump(data, f, indent=4)

print(f"Saved the best model")
# Out:
# Saved the best model
