# %%
import pandas as pd
import matplotlib.pyplot as plt
from time import time
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import SMOTE
from sentence_transformers import SentenceTransformer
from imblearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("../PreProcessingResumes/processed_data/Resume/train.csv")
df.head()
# Out:
#          ID                                         Resume_str  \
# 0  28111403  president chief executive officer executive pr...
# 1  29908929  business development marketing summary busines...
# 2  15261348  chef restaurant manager summary chef year high...
# 3  75435017  charge nurse professional summary objective ob...
# 4  41152404  test analyst intern contractor profile year pr...
#
#                  Category
# 0  INFORMATION-TECHNOLOGY
# 1    BUSINESS-DEVELOPMENT
# 2                    CHEF
# 3              HEALTHCARE
# 4  INFORMATION-TECHNOLOGY

# %%
# Convert resumes column to a list
resumes = df["Resume_str"].tolist()
    
# Encode category labels as integers
encoder = LabelEncoder()
labels = encoder.fit_transform(df["Category"])
category_names = encoder.classes_.tolist()

# %%
# Load the SBERT model for generating sentence embeddings
sbert_model = SentenceTransformer('all-MiniLM-L12-v2')

# %%
# Generate SBERT embeddings
resumes_embed = sbert_model.encode(resumes, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/63 [00:00<?, ?it/s]

# %% [markdown]
# ### Random Forest Classifier

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
class_counts = df['Category'].value_counts()
min_classes = class_counts[class_counts < 0.75*class_counts.mean()].index.tolist()

print(f"Applying SMOTE to classes: {min_classes}")

target_size = int(0.75*class_counts.max())
sampling_strategy = {cls: target_size for cls in min_classes}

# %%
pipeline = Pipeline(steps=[
    ('smote', SMOTE(sampling_strategy=sampling_strategy, random_state=42, k_neighbors=4)),
    ('clf', RandomForestClassifier(random_state=42, n_jobs=5))
])

# %%
param_grid = {
    'clf__n_estimators': [400, 700],
    'clf__max_features': ['sqrt', 'log2'],
    'clf__max_depth' : [5, 7, 8],
    'clf__criterion' : ['gini', 'entropy'],
    'clf__min_samples_split': [10],
    'clf__min_samples_leaf': [15]
}

scoring = ['accuracy', 'f1_weighted', 'precision_weighted', 'recall_weighted']

grid = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=skf,
    scoring= scoring,
    refit = False,
    return_train_score=True,
    n_jobs=-1
)

start = time()
grid_search = grid.fit(resumes_embed, labels)

print(f"GridSearchCV took {(time() - start):.2f} seconds for {len(grid_search.cv_results_['params'])} candidates parameter settings.")
# Out:
# GridSearchCV took 669.67 seconds for 24 candidates parameter settings.

# %%
# Convert the cross-validation results from GridSearchCV into a pandas DataFrame
results_df = pd.DataFrame(grid_search.cv_results_)

# Sort the results by the weighted F1 score in descending order
results_df = results_df.sort_values(by='mean_test_f1_weighted', ascending=False).reset_index(drop=True)

# %%
for i in range(len(results_df)):
    print(f"\n[{i+1}] Params: {results_df['params'][i]}")
    
    for metric in scoring:
        
        print(f"{metric.upper()}:")
        print(f"\tTRAIN:", end='')
        for fold in range(skf.get_n_splits()):
            print(f"\tFold {fold+1}: {results_df[f'split{fold}_train_{metric}'][i]:.4f}", end='')
        print(f"\t\tMean: {results_df[f'mean_train_{metric}'][i]:.4f}", end='')
        print(f"\tStd: {results_df[f'std_train_{metric}'][i]:.4f}")

        print(f"\tTEST:", end='')
        for fold in range(skf.get_n_splits()):
            print(f"\tFold {fold+1}: {results_df[f'split{fold}_test_{metric}'][i]:.4f}", end='')
        print(f"\t\tMean: {results_df[f'mean_test_{metric}'][i]:.4f}", end='')
        print(f"\tStd: {results_df[f'std_test_{metric}'][i]:.4f}\n")
# Out:
# [1] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 8, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9314	Fold 2: 0.9377	Fold 3: 0.9402	Fold 4: 0.9346	Fold 5: 0.9377		Mean: 0.9363  	Std: 0.0031
# 	TEST:	Fold 1: 0.7588	Fold 2: 0.7355	Fold 3: 0.7254	Fold 4: 0.7607	Fold 5: 0.7708		Mean: 0.7502  	Std: 0.0169
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9311	Fold 2: 0.9377	Fold 3: 0.9401	Fold 4: 0.9344	Fold 5: 0.9377		Mean: 0.9362  	Std: 0.0031
# 	TEST:	Fold 1: 0.7543	Fold 2: 0.7328	Fold 3: 0.7193	Fold 4: 0.7572	Fold 5: 0.7674		Mean: 0.7462  	Std: 0.0176
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9336	Fold 2: 0.9396	Fold 3: 0.9418	Fold 4: 0.9369	Fold 5: 0.9393		Mean: 0.9382  	Std: 0.0028
# 	TEST:	Fold 1: 0.7644	Fold 2: 0.7501	Fold 3: 0.7223	Fold 4: 0.7691	Fold 5: 0.7776		Mean: 0.7567  	Std: 0.0194
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9314	Fold 2: 0.9377	Fold 3: 0.9402	Fold 4: 0.9346	Fold 5: 0.9377		Mean: 0.9363  	Std: 0.0031
# 	TEST:	Fold 1: 0.7588	Fold 2: 0.7355	Fold 3: 0.7254	Fold 4: 0.7607	Fold 5: 0.7708		Mean: 0.7502  	Std: 0.0169
#
#
# [2] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 8, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9282	Fold 2: 0.9264	Fold 3: 0.9383	Fold 4: 0.9396	Fold 5: 0.9408		Mean: 0.9347  	Std: 0.0061
# 	TEST:	Fold 1: 0.7613	Fold 2: 0.7305	Fold 3: 0.7431	Fold 4: 0.7431	Fold 5: 0.7607		Mean: 0.7477  	Std: 0.0118
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9279	Fold 2: 0.9261	Fold 3: 0.9381	Fold 4: 0.9395	Fold 5: 0.9408		Mean: 0.9345  	Std: 0.0062
# 	TEST:	Fold 1: 0.7568	Fold 2: 0.7281	Fold 3: 0.7372	Fold 4: 0.7430	Fold 5: 0.7607		Mean: 0.7452  	Std: 0.0121
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9303	Fold 2: 0.9285	Fold 3: 0.9399	Fold 4: 0.9420	Fold 5: 0.9424		Mean: 0.9366  	Std: 0.0060
# 	TEST:	Fold 1: 0.7691	Fold 2: 0.7417	Fold 3: 0.7423	Fold 4: 0.7598	Fold 5: 0.7771		Mean: 0.7580  	Std: 0.0142
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9282	Fold 2: 0.9264	Fold 3: 0.9383	Fold 4: 0.9396	Fold 5: 0.9408		Mean: 0.9347  	Std: 0.0061
# 	TEST:	Fold 1: 0.7613	Fold 2: 0.7305	Fold 3: 0.7431	Fold 4: 0.7431	Fold 5: 0.7607		Mean: 0.7477  	Std: 0.0118
#
#
# [3] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9339	Fold 2: 0.9364	Fold 3: 0.9390	Fold 4: 0.9402	Fold 5: 0.9408		Mean: 0.9381  	Std: 0.0026
# 	TEST:	Fold 1: 0.7538	Fold 2: 0.7204	Fold 3: 0.7355	Fold 4: 0.7557	Fold 5: 0.7657		Mean: 0.7462  	Std: 0.0162
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9338	Fold 2: 0.9364	Fold 3: 0.9387	Fold 4: 0.9401	Fold 5: 0.9407		Mean: 0.9380  	Std: 0.0025
# 	TEST:	Fold 1: 0.7518	Fold 2: 0.7183	Fold 3: 0.7310	Fold 4: 0.7559	Fold 5: 0.7662		Mean: 0.7446  	Std: 0.0175
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9361	Fold 2: 0.9384	Fold 3: 0.9407	Fold 4: 0.9422	Fold 5: 0.9417		Mean: 0.9398  	Std: 0.0022
# 	TEST:	Fold 1: 0.7622	Fold 2: 0.7306	Fold 3: 0.7357	Fold 4: 0.7719	Fold 5: 0.7804		Mean: 0.7562  	Std: 0.0197
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9339	Fold 2: 0.9364	Fold 3: 0.9390	Fold 4: 0.9402	Fold 5: 0.9408		Mean: 0.9381  	Std: 0.0026
# 	TEST:	Fold 1: 0.7538	Fold 2: 0.7204	Fold 3: 0.7355	Fold 4: 0.7557	Fold 5: 0.7657		Mean: 0.7462  	Std: 0.0162
#
#
# [4] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 8, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9270	Fold 2: 0.9333	Fold 3: 0.9402	Fold 4: 0.9396	Fold 5: 0.9402		Mean: 0.9361  	Std: 0.0052
# 	TEST:	Fold 1: 0.7538	Fold 2: 0.7204	Fold 3: 0.7456	Fold 4: 0.7456	Fold 5: 0.7632		Mean: 0.7457  	Std: 0.0142
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9266	Fold 2: 0.9332	Fold 3: 0.9400	Fold 4: 0.9396	Fold 5: 0.9401		Mean: 0.9359  	Std: 0.0053
# 	TEST:	Fold 1: 0.7499	Fold 2: 0.7188	Fold 3: 0.7416	Fold 4: 0.7433	Fold 5: 0.7620		Mean: 0.7431  	Std: 0.0141
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9289	Fold 2: 0.9354	Fold 3: 0.9419	Fold 4: 0.9416	Fold 5: 0.9412		Mean: 0.9378  	Std: 0.0050
# 	TEST:	Fold 1: 0.7598	Fold 2: 0.7331	Fold 3: 0.7486	Fold 4: 0.7590	Fold 5: 0.7789		Mean: 0.7559  	Std: 0.0150
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9270	Fold 2: 0.9333	Fold 3: 0.9402	Fold 4: 0.9396	Fold 5: 0.9402		Mean: 0.9361  	Std: 0.0052
# 	TEST:	Fold 1: 0.7538	Fold 2: 0.7204	Fold 3: 0.7456	Fold 4: 0.7456	Fold 5: 0.7632		Mean: 0.7457  	Std: 0.0142
#
#
# [5] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 10, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9295	Fold 2: 0.9364	Fold 3: 0.9402	Fold 4: 0.9415	Fold 5: 0.9452		Mean: 0.9386  	Std: 0.0053
# 	TEST:	Fold 1: 0.7613	Fold 2: 0.7305	Fold 3: 0.7229	Fold 4: 0.7456	Fold 5: 0.7708		Mean: 0.7462  	Std: 0.0180
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9291	Fold 2: 0.9364	Fold 3: 0.9401	Fold 4: 0.9413	Fold 5: 0.9454		Mean: 0.9385  	Std: 0.0055
# 	TEST:	Fold 1: 0.7554	Fold 2: 0.7282	Fold 3: 0.7147	Fold 4: 0.7459	Fold 5: 0.7673		Mean: 0.7423  	Std: 0.0188
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9316	Fold 2: 0.9382	Fold 3: 0.9420	Fold 4: 0.9433	Fold 5: 0.9469		Mean: 0.9404  	Std: 0.0052
# 	TEST:	Fold 1: 0.7656	Fold 2: 0.7439	Fold 3: 0.7198	Fold 4: 0.7608	Fold 5: 0.7818		Mean: 0.7544  	Std: 0.0211
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9295	Fold 2: 0.9364	Fold 3: 0.9402	Fold 4: 0.9415	Fold 5: 0.9452		Mean: 0.9386  	Std: 0.0053
# 	TEST:	Fold 1: 0.7613	Fold 2: 0.7305	Fold 3: 0.7229	Fold 4: 0.7456	Fold 5: 0.7708		Mean: 0.7462  	Std: 0.0180
#
#
# [6] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 10, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9320	Fold 2: 0.9383	Fold 3: 0.9440	Fold 4: 0.9434	Fold 5: 0.9465		Mean: 0.9408  	Std: 0.0052
# 	TEST:	Fold 1: 0.7538	Fold 2: 0.7305	Fold 3: 0.7305	Fold 4: 0.7557	Fold 5: 0.7657		Mean: 0.7472  	Std: 0.0143
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9316	Fold 2: 0.9383	Fold 3: 0.9439	Fold 4: 0.9432	Fold 5: 0.9465		Mean: 0.9407  	Std: 0.0052
# 	TEST:	Fold 1: 0.7476	Fold 2: 0.7263	Fold 3: 0.7226	Fold 4: 0.7535	Fold 5: 0.7610		Mean: 0.7422  	Std: 0.0152
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9341	Fold 2: 0.9401	Fold 3: 0.9454	Fold 4: 0.9453	Fold 5: 0.9478		Mean: 0.9426  	Std: 0.0049
# 	TEST:	Fold 1: 0.7545	Fold 2: 0.7407	Fold 3: 0.7252	Fold 4: 0.7643	Fold 5: 0.7732		Mean: 0.7516  	Std: 0.0170
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9320	Fold 2: 0.9383	Fold 3: 0.9440	Fold 4: 0.9434	Fold 5: 0.9465		Mean: 0.9408  	Std: 0.0052
# 	TEST:	Fold 1: 0.7538	Fold 2: 0.7305	Fold 3: 0.7305	Fold 4: 0.7557	Fold 5: 0.7657		Mean: 0.7472  	Std: 0.0143
#
#
# [7] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 9, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9314	Fold 2: 0.9364	Fold 3: 0.9383	Fold 4: 0.9377	Fold 5: 0.9396		Mean: 0.9367  	Std: 0.0028
# 	TEST:	Fold 1: 0.7588	Fold 2: 0.7204	Fold 3: 0.7305	Fold 4: 0.7456	Fold 5: 0.7632		Mean: 0.7437  	Std: 0.0163
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9312	Fold 2: 0.9364	Fold 3: 0.9381	Fold 4: 0.9375	Fold 5: 0.9395		Mean: 0.9365  	Std: 0.0028
# 	TEST:	Fold 1: 0.7563	Fold 2: 0.7192	Fold 3: 0.7238	Fold 4: 0.7453	Fold 5: 0.7634		Mean: 0.7416  	Std: 0.0175
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9335	Fold 2: 0.9382	Fold 3: 0.9401	Fold 4: 0.9395	Fold 5: 0.9405		Mean: 0.9384  	Std: 0.0025
# 	TEST:	Fold 1: 0.7635	Fold 2: 0.7344	Fold 3: 0.7302	Fold 4: 0.7618	Fold 5: 0.7795		Mean: 0.7539  	Std: 0.0187
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9314	Fold 2: 0.9364	Fold 3: 0.9383	Fold 4: 0.9377	Fold 5: 0.9396		Mean: 0.9367  	Std: 0.0028
# 	TEST:	Fold 1: 0.7588	Fold 2: 0.7204	Fold 3: 0.7305	Fold 4: 0.7456	Fold 5: 0.7632		Mean: 0.7437  	Std: 0.0163
#
#
# [8] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 9, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9345	Fold 2: 0.9383	Fold 3: 0.9434	Fold 4: 0.9415	Fold 5: 0.9452		Mean: 0.9406  	Std: 0.0038
# 	TEST:	Fold 1: 0.7588	Fold 2: 0.7229	Fold 3: 0.7305	Fold 4: 0.7506	Fold 5: 0.7657		Mean: 0.7457  	Std: 0.0164
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9342	Fold 2: 0.9384	Fold 3: 0.9432	Fold 4: 0.9413	Fold 5: 0.9452		Mean: 0.9405  	Std: 0.0038
# 	TEST:	Fold 1: 0.7523	Fold 2: 0.7182	Fold 3: 0.7228	Fold 4: 0.7482	Fold 5: 0.7609		Mean: 0.7405  	Std: 0.0169
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9366	Fold 2: 0.9403	Fold 3: 0.9446	Fold 4: 0.9433	Fold 5: 0.9466		Mean: 0.9423  	Std: 0.0035
# 	TEST:	Fold 1: 0.7547	Fold 2: 0.7314	Fold 3: 0.7254	Fold 4: 0.7592	Fold 5: 0.7726		Mean: 0.7487  	Std: 0.0176
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9345	Fold 2: 0.9383	Fold 3: 0.9434	Fold 4: 0.9415	Fold 5: 0.9452		Mean: 0.9406  	Std: 0.0038
# 	TEST:	Fold 1: 0.7588	Fold 2: 0.7229	Fold 3: 0.7305	Fold 4: 0.7506	Fold 5: 0.7657		Mean: 0.7457  	Std: 0.0164
#
#
# [9] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 9, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9320	Fold 2: 0.9371	Fold 3: 0.9434	Fold 4: 0.9421	Fold 5: 0.9440		Mean: 0.9397  	Std: 0.0046
# 	TEST:	Fold 1: 0.7714	Fold 2: 0.7280	Fold 3: 0.7280	Fold 4: 0.7406	Fold 5: 0.7582		Mean: 0.7452  	Std: 0.0171
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9317	Fold 2: 0.9370	Fold 3: 0.9433	Fold 4: 0.9420	Fold 5: 0.9441		Mean: 0.9396  	Std: 0.0047
# 	TEST:	Fold 1: 0.7646	Fold 2: 0.7236	Fold 3: 0.7201	Fold 4: 0.7409	Fold 5: 0.7521		Mean: 0.7402  	Std: 0.0168
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9342	Fold 2: 0.9387	Fold 3: 0.9451	Fold 4: 0.9439	Fold 5: 0.9455		Mean: 0.9415  	Std: 0.0044
# 	TEST:	Fold 1: 0.7752	Fold 2: 0.7341	Fold 3: 0.7255	Fold 4: 0.7548	Fold 5: 0.7647		Mean: 0.7509  	Std: 0.0186
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9320	Fold 2: 0.9371	Fold 3: 0.9434	Fold 4: 0.9421	Fold 5: 0.9440		Mean: 0.9397  	Std: 0.0046
# 	TEST:	Fold 1: 0.7714	Fold 2: 0.7280	Fold 3: 0.7280	Fold 4: 0.7406	Fold 5: 0.7582		Mean: 0.7452  	Std: 0.0171
#
#
# [10] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 9, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9301	Fold 2: 0.9333	Fold 3: 0.9383	Fold 4: 0.9383	Fold 5: 0.9402		Mean: 0.9361  	Std: 0.0038
# 	TEST:	Fold 1: 0.7588	Fold 2: 0.7204	Fold 3: 0.7305	Fold 4: 0.7456	Fold 5: 0.7582		Mean: 0.7427  	Std: 0.0152
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9300	Fold 2: 0.9332	Fold 3: 0.9381	Fold 4: 0.9382	Fold 5: 0.9402		Mean: 0.9360  	Std: 0.0037
# 	TEST:	Fold 1: 0.7552	Fold 2: 0.7181	Fold 3: 0.7251	Fold 4: 0.7454	Fold 5: 0.7567		Mean: 0.7401  	Std: 0.0158
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9325	Fold 2: 0.9354	Fold 3: 0.9402	Fold 4: 0.9405	Fold 5: 0.9413		Mean: 0.9380  	Std: 0.0034
# 	TEST:	Fold 1: 0.7627	Fold 2: 0.7297	Fold 3: 0.7308	Fold 4: 0.7609	Fold 5: 0.7712		Mean: 0.7511  	Std: 0.0173
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9301	Fold 2: 0.9333	Fold 3: 0.9383	Fold 4: 0.9383	Fold 5: 0.9402		Mean: 0.9361  	Std: 0.0038
# 	TEST:	Fold 1: 0.7588	Fold 2: 0.7204	Fold 3: 0.7305	Fold 4: 0.7456	Fold 5: 0.7582		Mean: 0.7427  	Std: 0.0152
#
#
# [11] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 8, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9276	Fold 2: 0.9377	Fold 3: 0.9396	Fold 4: 0.9358	Fold 5: 0.9402		Mean: 0.9362  	Std: 0.0046
# 	TEST:	Fold 1: 0.7613	Fold 2: 0.7380	Fold 3: 0.7179	Fold 4: 0.7481	Fold 5: 0.7506		Mean: 0.7432  	Std: 0.0147
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9272	Fold 2: 0.9376	Fold 3: 0.9394	Fold 4: 0.9358	Fold 5: 0.9403		Mean: 0.9360  	Std: 0.0047
# 	TEST:	Fold 1: 0.7543	Fold 2: 0.7358	Fold 3: 0.7117	Fold 4: 0.7442	Fold 5: 0.7463		Mean: 0.7385  	Std: 0.0146
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9297	Fold 2: 0.9394	Fold 3: 0.9413	Fold 4: 0.9382	Fold 5: 0.9417		Mean: 0.9380  	Std: 0.0044
# 	TEST:	Fold 1: 0.7608	Fold 2: 0.7519	Fold 3: 0.7155	Fold 4: 0.7557	Fold 5: 0.7597		Mean: 0.7487  	Std: 0.0169
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9276	Fold 2: 0.9377	Fold 3: 0.9396	Fold 4: 0.9358	Fold 5: 0.9402		Mean: 0.9362  	Std: 0.0046
# 	TEST:	Fold 1: 0.7613	Fold 2: 0.7380	Fold 3: 0.7179	Fold 4: 0.7481	Fold 5: 0.7506		Mean: 0.7432  	Std: 0.0147
#
#
# [12] Params: {'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9194	Fold 2: 0.9182	Fold 3: 0.9257	Fold 4: 0.9226	Fold 5: 0.9176		Mean: 0.9207  	Std: 0.0031
# 	TEST:	Fold 1: 0.7462	Fold 2: 0.7254	Fold 3: 0.7380	Fold 4: 0.7506	Fold 5: 0.7506		Mean: 0.7422  	Std: 0.0096
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9189	Fold 2: 0.9180	Fold 3: 0.9255	Fold 4: 0.9225	Fold 5: 0.9176		Mean: 0.9205  	Std: 0.0030
# 	TEST:	Fold 1: 0.7399	Fold 2: 0.7219	Fold 3: 0.7329	Fold 4: 0.7476	Fold 5: 0.7490		Mean: 0.7383  	Std: 0.0100
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9220	Fold 2: 0.9211	Fold 3: 0.9280	Fold 4: 0.9250	Fold 5: 0.9199		Mean: 0.9232  	Std: 0.0029
# 	TEST:	Fold 1: 0.7445	Fold 2: 0.7311	Fold 3: 0.7377	Fold 4: 0.7628	Fold 5: 0.7668		Mean: 0.7486  	Std: 0.0140
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9194	Fold 2: 0.9182	Fold 3: 0.9257	Fold 4: 0.9226	Fold 5: 0.9176		Mean: 0.9207  	Std: 0.0031
# 	TEST:	Fold 1: 0.7462	Fold 2: 0.7254	Fold 3: 0.7380	Fold 4: 0.7506	Fold 5: 0.7506		Mean: 0.7422  	Std: 0.0096
#
#
# [13] Params: {'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9087	Fold 2: 0.9100	Fold 3: 0.9182	Fold 4: 0.9062	Fold 5: 0.9050		Mean: 0.9096  	Std: 0.0046
# 	TEST:	Fold 1: 0.7513	Fold 2: 0.7229	Fold 3: 0.7229	Fold 4: 0.7531	Fold 5: 0.7531		Mean: 0.7407  	Std: 0.0145
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9084	Fold 2: 0.9095	Fold 3: 0.9180	Fold 4: 0.9063	Fold 5: 0.9047		Mean: 0.9094  	Std: 0.0046
# 	TEST:	Fold 1: 0.7470	Fold 2: 0.7224	Fold 3: 0.7203	Fold 4: 0.7503	Fold 5: 0.7512		Mean: 0.7382  	Std: 0.0139
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9112	Fold 2: 0.9125	Fold 3: 0.9207	Fold 4: 0.9101	Fold 5: 0.9066		Mean: 0.9122  	Std: 0.0047
# 	TEST:	Fold 1: 0.7539	Fold 2: 0.7373	Fold 3: 0.7284	Fold 4: 0.7653	Fold 5: 0.7698		Mean: 0.7509  	Std: 0.0159
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9087	Fold 2: 0.9100	Fold 3: 0.9182	Fold 4: 0.9062	Fold 5: 0.9050		Mean: 0.9096  	Std: 0.0046
# 	TEST:	Fold 1: 0.7513	Fold 2: 0.7229	Fold 3: 0.7229	Fold 4: 0.7531	Fold 5: 0.7531		Mean: 0.7407  	Std: 0.0145
#
#
# [14] Params: {'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9150	Fold 2: 0.9194	Fold 3: 0.9295	Fold 4: 0.9201	Fold 5: 0.9201		Mean: 0.9208  	Std: 0.0047
# 	TEST:	Fold 1: 0.7538	Fold 2: 0.7254	Fold 3: 0.7229	Fold 4: 0.7531	Fold 5: 0.7557		Mean: 0.7422  	Std: 0.0147
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9147	Fold 2: 0.9191	Fold 3: 0.9292	Fold 4: 0.9201	Fold 5: 0.9202		Mean: 0.9206  	Std: 0.0047
# 	TEST:	Fold 1: 0.7486	Fold 2: 0.7206	Fold 3: 0.7180	Fold 4: 0.7492	Fold 5: 0.7525		Mean: 0.7378  	Std: 0.0152
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9184	Fold 2: 0.9216	Fold 3: 0.9313	Fold 4: 0.9229	Fold 5: 0.9225		Mean: 0.9234  	Std: 0.0043
# 	TEST:	Fold 1: 0.7562	Fold 2: 0.7304	Fold 3: 0.7254	Fold 4: 0.7641	Fold 5: 0.7694		Mean: 0.7491  	Std: 0.0179
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9150	Fold 2: 0.9194	Fold 3: 0.9295	Fold 4: 0.9201	Fold 5: 0.9201		Mean: 0.9208  	Std: 0.0047
# 	TEST:	Fold 1: 0.7538	Fold 2: 0.7254	Fold 3: 0.7229	Fold 4: 0.7531	Fold 5: 0.7557		Mean: 0.7422  	Std: 0.0147
#
#
# [15] Params: {'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9062	Fold 2: 0.9113	Fold 3: 0.9144	Fold 4: 0.9043	Fold 5: 0.9056		Mean: 0.9084  	Std: 0.0038
# 	TEST:	Fold 1: 0.7538	Fold 2: 0.7305	Fold 3: 0.7179	Fold 4: 0.7456	Fold 5: 0.7531		Mean: 0.7402  	Std: 0.0140
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9060	Fold 2: 0.9110	Fold 3: 0.9143	Fold 4: 0.9046	Fold 5: 0.9052		Mean: 0.9082  	Std: 0.0038
# 	TEST:	Fold 1: 0.7497	Fold 2: 0.7291	Fold 3: 0.7153	Fold 4: 0.7427	Fold 5: 0.7519		Mean: 0.7378  	Std: 0.0138
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9093	Fold 2: 0.9140	Fold 3: 0.9174	Fold 4: 0.9078	Fold 5: 0.9072		Mean: 0.9111  	Std: 0.0039
# 	TEST:	Fold 1: 0.7600	Fold 2: 0.7467	Fold 3: 0.7232	Fold 4: 0.7554	Fold 5: 0.7701		Mean: 0.7511  	Std: 0.0159
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9062	Fold 2: 0.9113	Fold 3: 0.9144	Fold 4: 0.9043	Fold 5: 0.9056		Mean: 0.9084  	Std: 0.0038
# 	TEST:	Fold 1: 0.7538	Fold 2: 0.7305	Fold 3: 0.7179	Fold 4: 0.7456	Fold 5: 0.7531		Mean: 0.7402  	Std: 0.0140
#
#
# [16] Params: {'clf__criterion': 'entropy', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9314	Fold 2: 0.9352	Fold 3: 0.9383	Fold 4: 0.9390	Fold 5: 0.9421		Mean: 0.9372  	Std: 0.0036
# 	TEST:	Fold 1: 0.7513	Fold 2: 0.7254	Fold 3: 0.7280	Fold 4: 0.7456	Fold 5: 0.7506		Mean: 0.7402  	Std: 0.0112
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9313	Fold 2: 0.9351	Fold 3: 0.9381	Fold 4: 0.9388	Fold 5: 0.9419		Mean: 0.9371  	Std: 0.0036
# 	TEST:	Fold 1: 0.7475	Fold 2: 0.7234	Fold 3: 0.7222	Fold 4: 0.7466	Fold 5: 0.7489		Mean: 0.7377  	Std: 0.0122
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9336	Fold 2: 0.9372	Fold 3: 0.9401	Fold 4: 0.9411	Fold 5: 0.9430		Mean: 0.9390  	Std: 0.0033
# 	TEST:	Fold 1: 0.7577	Fold 2: 0.7369	Fold 3: 0.7252	Fold 4: 0.7634	Fold 5: 0.7622		Mean: 0.7491  	Std: 0.0153
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9314	Fold 2: 0.9352	Fold 3: 0.9383	Fold 4: 0.9390	Fold 5: 0.9421		Mean: 0.9372  	Std: 0.0036
# 	TEST:	Fold 1: 0.7513	Fold 2: 0.7254	Fold 3: 0.7280	Fold 4: 0.7456	Fold 5: 0.7506		Mean: 0.7402  	Std: 0.0112
#
#
# [17] Params: {'clf__criterion': 'gini', 'clf__max_depth': 9, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9037	Fold 2: 0.9012	Fold 3: 0.9081	Fold 4: 0.8962	Fold 5: 0.8949		Mean: 0.9008  	Std: 0.0049
# 	TEST:	Fold 1: 0.7513	Fold 2: 0.7229	Fold 3: 0.7154	Fold 4: 0.7456	Fold 5: 0.7582		Mean: 0.7387  	Std: 0.0166
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9033	Fold 2: 0.9004	Fold 3: 0.9080	Fold 4: 0.8963	Fold 5: 0.8944		Mean: 0.9005  	Std: 0.0049
# 	TEST:	Fold 1: 0.7481	Fold 2: 0.7227	Fold 3: 0.7133	Fold 4: 0.7427	Fold 5: 0.7549		Mean: 0.7363  	Std: 0.0158
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9069	Fold 2: 0.9034	Fold 3: 0.9116	Fold 4: 0.9014	Fold 5: 0.8963		Mean: 0.9039  	Std: 0.0051
# 	TEST:	Fold 1: 0.7606	Fold 2: 0.7414	Fold 3: 0.7240	Fold 4: 0.7552	Fold 5: 0.7752		Mean: 0.7513  	Std: 0.0174
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9037	Fold 2: 0.9012	Fold 3: 0.9081	Fold 4: 0.8962	Fold 5: 0.8949		Mean: 0.9008  	Std: 0.0049
# 	TEST:	Fold 1: 0.7513	Fold 2: 0.7229	Fold 3: 0.7154	Fold 4: 0.7456	Fold 5: 0.7582		Mean: 0.7387  	Std: 0.0166
#
#
# [18] Params: {'clf__criterion': 'gini', 'clf__max_depth': 9, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9055	Fold 2: 0.9119	Fold 3: 0.9194	Fold 4: 0.9100	Fold 5: 0.9094		Mean: 0.9113  	Std: 0.0046
# 	TEST:	Fold 1: 0.7563	Fold 2: 0.7280	Fold 3: 0.7254	Fold 4: 0.7481	Fold 5: 0.7330		Mean: 0.7382  	Std: 0.0120
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9054	Fold 2: 0.9117	Fold 3: 0.9192	Fold 4: 0.9097	Fold 5: 0.9094		Mean: 0.9111  	Std: 0.0046
# 	TEST:	Fold 1: 0.7522	Fold 2: 0.7264	Fold 3: 0.7227	Fold 4: 0.7462	Fold 5: 0.7304		Mean: 0.7356  	Std: 0.0116
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9096	Fold 2: 0.9144	Fold 3: 0.9219	Fold 4: 0.9130	Fold 5: 0.9112		Mean: 0.9140  	Std: 0.0043
# 	TEST:	Fold 1: 0.7607	Fold 2: 0.7380	Fold 3: 0.7331	Fold 4: 0.7637	Fold 5: 0.7496		Mean: 0.7490  	Std: 0.0121
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9055	Fold 2: 0.9119	Fold 3: 0.9194	Fold 4: 0.9100	Fold 5: 0.9094		Mean: 0.9113  	Std: 0.0046
# 	TEST:	Fold 1: 0.7563	Fold 2: 0.7280	Fold 3: 0.7254	Fold 4: 0.7481	Fold 5: 0.7330		Mean: 0.7382  	Std: 0.0120
#
#
# [19] Params: {'clf__criterion': 'gini', 'clf__max_depth': 9, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9011	Fold 2: 0.8974	Fold 3: 0.9094	Fold 4: 0.8899	Fold 5: 0.8955		Mean: 0.8987  	Std: 0.0065
# 	TEST:	Fold 1: 0.7588	Fold 2: 0.7179	Fold 3: 0.7305	Fold 4: 0.7330	Fold 5: 0.7506		Mean: 0.7382  	Std: 0.0147
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9007	Fold 2: 0.8967	Fold 3: 0.9090	Fold 4: 0.8900	Fold 5: 0.8949		Mean: 0.8983  	Std: 0.0064
# 	TEST:	Fold 1: 0.7551	Fold 2: 0.7169	Fold 3: 0.7273	Fold 4: 0.7298	Fold 5: 0.7467		Mean: 0.7352  	Std: 0.0138
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9043	Fold 2: 0.9004	Fold 3: 0.9129	Fold 4: 0.8947	Fold 5: 0.8968		Mean: 0.9018  	Std: 0.0064
# 	TEST:	Fold 1: 0.7657	Fold 2: 0.7334	Fold 3: 0.7388	Fold 4: 0.7439	Fold 5: 0.7678		Mean: 0.7499  	Std: 0.0142
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9011	Fold 2: 0.8974	Fold 3: 0.9094	Fold 4: 0.8899	Fold 5: 0.8955		Mean: 0.8987  	Std: 0.0065
# 	TEST:	Fold 1: 0.7588	Fold 2: 0.7179	Fold 3: 0.7305	Fold 4: 0.7330	Fold 5: 0.7506		Mean: 0.7382  	Std: 0.0147
#
#
# [20] Params: {'clf__criterion': 'gini', 'clf__max_depth': 8, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8992	Fold 2: 0.8999	Fold 3: 0.9087	Fold 4: 0.8930	Fold 5: 0.8943		Mean: 0.8990  	Std: 0.0056
# 	TEST:	Fold 1: 0.7487	Fold 2: 0.7280	Fold 3: 0.7280	Fold 4: 0.7406	Fold 5: 0.7531		Mean: 0.7397  	Std: 0.0104
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8991	Fold 2: 0.8989	Fold 3: 0.9083	Fold 4: 0.8928	Fold 5: 0.8940		Mean: 0.8986  	Std: 0.0055
# 	TEST:	Fold 1: 0.7414	Fold 2: 0.7239	Fold 3: 0.7250	Fold 4: 0.7319	Fold 5: 0.7509		Mean: 0.7346  	Std: 0.0103
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9038	Fold 2: 0.9022	Fold 3: 0.9117	Fold 4: 0.8976	Fold 5: 0.8969		Mean: 0.9024  	Std: 0.0053
# 	TEST:	Fold 1: 0.7440	Fold 2: 0.7358	Fold 3: 0.7377	Fold 4: 0.7443	Fold 5: 0.7714		Mean: 0.7467  	Std: 0.0128
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8992	Fold 2: 0.8999	Fold 3: 0.9087	Fold 4: 0.8930	Fold 5: 0.8943		Mean: 0.8990  	Std: 0.0056
# 	TEST:	Fold 1: 0.7487	Fold 2: 0.7280	Fold 3: 0.7280	Fold 4: 0.7406	Fold 5: 0.7531		Mean: 0.7397  	Std: 0.0104
#
#
# [21] Params: {'clf__criterion': 'gini', 'clf__max_depth': 9, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.9137	Fold 2: 0.9132	Fold 3: 0.9213	Fold 4: 0.9100	Fold 5: 0.9125		Mean: 0.9141  	Std: 0.0038
# 	TEST:	Fold 1: 0.7538	Fold 2: 0.7254	Fold 3: 0.7254	Fold 4: 0.7431	Fold 5: 0.7380		Mean: 0.7372  	Std: 0.0108
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9130	Fold 2: 0.9130	Fold 3: 0.9211	Fold 4: 0.9098	Fold 5: 0.9125		Mean: 0.9139  	Std: 0.0038
# 	TEST:	Fold 1: 0.7479	Fold 2: 0.7215	Fold 3: 0.7209	Fold 4: 0.7416	Fold 5: 0.7363		Mean: 0.7336  	Std: 0.0108
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9157	Fold 2: 0.9157	Fold 3: 0.9238	Fold 4: 0.9131	Fold 5: 0.9150		Mean: 0.9167  	Std: 0.0037
# 	TEST:	Fold 1: 0.7540	Fold 2: 0.7342	Fold 3: 0.7309	Fold 4: 0.7568	Fold 5: 0.7532		Mean: 0.7458  	Std: 0.0110
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9137	Fold 2: 0.9132	Fold 3: 0.9213	Fold 4: 0.9100	Fold 5: 0.9125		Mean: 0.9141  	Std: 0.0038
# 	TEST:	Fold 1: 0.7538	Fold 2: 0.7254	Fold 3: 0.7254	Fold 4: 0.7431	Fold 5: 0.7380		Mean: 0.7372  	Std: 0.0108
#
#
# [22] Params: {'clf__criterion': 'gini', 'clf__max_depth': 8, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8999	Fold 2: 0.9031	Fold 3: 0.9119	Fold 4: 0.8930	Fold 5: 0.8999		Mean: 0.9016  	Std: 0.0061
# 	TEST:	Fold 1: 0.7462	Fold 2: 0.7305	Fold 3: 0.7229	Fold 4: 0.7355	Fold 5: 0.7481		Mean: 0.7367  	Std: 0.0095
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8995	Fold 2: 0.9022	Fold 3: 0.9115	Fold 4: 0.8925	Fold 5: 0.8995		Mean: 0.9010  	Std: 0.0061
# 	TEST:	Fold 1: 0.7416	Fold 2: 0.7271	Fold 3: 0.7175	Fold 4: 0.7272	Fold 5: 0.7444		Mean: 0.7316  	Std: 0.0100
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.9042	Fold 2: 0.9052	Fold 3: 0.9149	Fold 4: 0.8975	Fold 5: 0.9024		Mean: 0.9048  	Std: 0.0057
# 	TEST:	Fold 1: 0.7502	Fold 2: 0.7400	Fold 3: 0.7238	Fold 4: 0.7386	Fold 5: 0.7626		Mean: 0.7430  	Std: 0.0129
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8999	Fold 2: 0.9031	Fold 3: 0.9119	Fold 4: 0.8930	Fold 5: 0.8999		Mean: 0.9016  	Std: 0.0061
# 	TEST:	Fold 1: 0.7462	Fold 2: 0.7305	Fold 3: 0.7229	Fold 4: 0.7355	Fold 5: 0.7481		Mean: 0.7367  	Std: 0.0095
#
#
# [23] Params: {'clf__criterion': 'gini', 'clf__max_depth': 8, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 700}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8873	Fold 2: 0.8861	Fold 3: 0.8993	Fold 4: 0.8779	Fold 5: 0.8817		Mean: 0.8865  	Std: 0.0072
# 	TEST:	Fold 1: 0.7513	Fold 2: 0.7179	Fold 3: 0.7229	Fold 4: 0.7280	Fold 5: 0.7481		Mean: 0.7336  	Std: 0.0135
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8869	Fold 2: 0.8851	Fold 3: 0.8991	Fold 4: 0.8777	Fold 5: 0.8809		Mean: 0.8859  	Std: 0.0073
# 	TEST:	Fold 1: 0.7459	Fold 2: 0.7136	Fold 3: 0.7204	Fold 4: 0.7249	Fold 5: 0.7429		Mean: 0.7295  	Std: 0.0127
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8916	Fold 2: 0.8895	Fold 3: 0.9039	Fold 4: 0.8834	Fold 5: 0.8835		Mean: 0.8904  	Std: 0.0075
# 	TEST:	Fold 1: 0.7586	Fold 2: 0.7292	Fold 3: 0.7322	Fold 4: 0.7404	Fold 5: 0.7604		Mean: 0.7442  	Std: 0.0131
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8873	Fold 2: 0.8861	Fold 3: 0.8993	Fold 4: 0.8779	Fold 5: 0.8817		Mean: 0.8865  	Std: 0.0072
# 	TEST:	Fold 1: 0.7513	Fold 2: 0.7179	Fold 3: 0.7229	Fold 4: 0.7280	Fold 5: 0.7481		Mean: 0.7336  	Std: 0.0135
#
#
# [24] Params: {'clf__criterion': 'gini', 'clf__max_depth': 8, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 15, 'clf__min_samples_split': 10, 'clf__n_estimators': 400}
# ACCURACY:
# 	TRAIN:	Fold 1: 0.8873	Fold 2: 0.8817	Fold 3: 0.8968	Fold 4: 0.8773	Fold 5: 0.8792		Mean: 0.8844  	Std: 0.0070
# 	TEST:	Fold 1: 0.7462	Fold 2: 0.7028	Fold 3: 0.7204	Fold 4: 0.7280	Fold 5: 0.7380		Mean: 0.7271  	Std: 0.0150
#
# F1_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8869	Fold 2: 0.8809	Fold 3: 0.8964	Fold 4: 0.8769	Fold 5: 0.8785		Mean: 0.8839  	Std: 0.0071
# 	TEST:	Fold 1: 0.7396	Fold 2: 0.7011	Fold 3: 0.7194	Fold 4: 0.7255	Fold 5: 0.7320		Mean: 0.7235  	Std: 0.0131
#
# PRECISION_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8911	Fold 2: 0.8859	Fold 3: 0.9001	Fold 4: 0.8816	Fold 5: 0.8812		Mean: 0.8880  	Std: 0.0070
# 	TEST:	Fold 1: 0.7441	Fold 2: 0.7187	Fold 3: 0.7314	Fold 4: 0.7410	Fold 5: 0.7538		Mean: 0.7378  	Std: 0.0119
#
# RECALL_WEIGHTED:
# 	TRAIN:	Fold 1: 0.8873	Fold 2: 0.8817	Fold 3: 0.8968	Fold 4: 0.8773	Fold 5: 0.8792		Mean: 0.8844  	Std: 0.0070
# 	TEST:	Fold 1: 0.7462	Fold 2: 0.7028	Fold 3: 0.7204	Fold 4: 0.7280	Fold 5: 0.7380		Mean: 0.7271  	Std: 0.0150

# %%
for metric in scoring:
    data_test = {}
    data_train = {}
    for i in range(len(results_df)):
        col_name = f'{i+1}'
        data_test[col_name] = [results_df[f'split{fold}_test_{metric}'][i] for fold in range(skf.get_n_splits())]
        data_train[col_name] = [results_df[f'split{fold}_train_{metric}'][i] for fold in range(skf.get_n_splits())]

    df_test = pd.DataFrame(data_test)
    df_train = pd.DataFrame(data_train)

    means_test = df_test.mean()
    stds_test = df_test.std()
    means_train = df_train.mean()
    stds_train = df_train.std()

    plt.figure(figsize=(max(6, len(results_df) * 0.75), 4))

    plt.errorbar(means_test.index, means_test.values, yerr=stds_test.values, fmt='-o', capsize=5, label='Test', color='blue')

    plt.errorbar(means_train.index, means_train.values, yerr=stds_train.values, fmt='--s', capsize=5, label='Train', color='orange')

    plt.ylabel(f'{metric} score')
    plt.xlabel('Combination of parameters')
    plt.title(f'Model comparison on {metric} (mean ± std)')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
for metric in scoring:
    data = {}
    for i in range(len(results_df)):
        col_name = f'{i+1}'
        data[col_name] = [results_df[f'split{fold}_test_{metric}'][i] for fold in range(skf.get_n_splits())]

    df_metric = pd.DataFrame(data)
    ax = df_metric.boxplot(figsize=(max(6, len(results_df) * 0.75), 4))
    ax.set_ylabel(f'{metric} score')
    ax.set_xlabel('Combination of parameters')
    plt.title(f'Model comparison on {metric}')
    plt.grid(True)
    plt.show()
