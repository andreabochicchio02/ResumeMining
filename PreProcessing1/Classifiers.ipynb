# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords, words
from wordcloud import WordCloud
import os

# %%
# Define the folder containing the processed CSV files
input_folder = "processed_data"

# %%
# Get the list of all CSV files in the folder
#csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]

# Create a dictionary to hold the DataFrames
#dfs = {}

# Loop through the files and create a DataFrame for each one
#for file in csv_files:
#    file_path = os.path.join(input_folder, file)
#    
#    # Load the CSV into a DataFrame
#    df = pd.read_csv(file_path)
#    
#    # Add the DataFrame to the dictionary using the filename (without extension) as the key
#    dfs[file] = df
#
#    print(f"Created DataFrame for file: {file}")

# %%
#dfs["Resume_processed_remove_numbers=False_use_dictionary=True_use_lemmatization=False_use_stemming=False.csv"].head()

# %%
df = pd.read_csv("processed_data/Resume_processed_remove_numbers=True_use_dictionary=True_use_lemmatization=True_use_stemming=False.csv")

# %%
count_vect = CountVectorizer(
    lowercase=True,
    binary = False,
    # stop_words = list(stop_words),      # TODO could be not useful, we already remove stop words in preprocess_text
    # ngram_range=(1,2),               # Considers unigrams and bigrams
    # max_df = 0.85,                    # Ignores words appearing in more than 85% of documents (too common)
    # min_df = 2,                       # Keeps words appearing in at least 2 documents (filters rare words)
)

# %%
# Split data into training and validation
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df['Resume_str'], df['Category'], test_size=0.2, random_state=42, stratify=df['Category'])


# Print the sizes of the split datasets
print("Train data size:", X_train.shape)
print("Validation data size:", X_test.shape)
# Out:
# Train data size: (1986,)
# Validation data size: (497,)

# %%
conuntvectorizer_train = count_vect.fit_transform(X_train).astype(float)
conuntvectorizer_test = count_vect.transform(X_test).astype(float)

# %%
len(count_vect.vocabulary_)
# Out:
# 12123

# %%
tokens = count_vect.get_feature_names_out()
tokens[:100]
# Out:
# array(['aa', 'aam', 'aardwolf', 'aba', 'abac', 'abacus', 'abandon',
#        'abandoned', 'abatement', 'abbey', 'abduction', 'abide', 'abiding',
#        'abigail', 'ability', 'ablation', 'able', 'abnormal', 'aboard',
#        'abode', 'aboriginal', 'aborted', 'abraxas', 'abreast', 'abroad',
#        'absence', 'absent', 'absentee', 'absenteeism', 'absolute',
#        'absolutely', 'absorb', 'absorbed', 'absorbing', 'absorption',
#        'abstinence', 'abstract', 'abstracted', 'abstraction', 'abu',
#        'abundance', 'abundant', 'abuse', 'abusive', 'academic',
#        'academically', 'academy', 'acca', 'accelerate', 'accelerated',
#        'acceleration', 'accelerator', 'accent', 'accept', 'acceptability',
#        'acceptable', 'acceptance', 'accepted', 'access', 'accessibility',
#        'accessible', 'accession', 'accessory', 'accident', 'accidental',
#        'accidentally', 'acclimate', 'accolade', 'accommodate',
#        'accommodating', 'accommodation', 'accompaniment', 'accompanist',
#        'accompany', 'accomplish', 'accomplished', 'accomplishment',
#        'accordance', 'according', 'accordingly', 'account',
#        'accountability', 'accountable', 'accountancy', 'accountant',
#        'accounting', 'accreditation', 'accredited', 'accretion',
#        'accrual', 'accrue', 'accumulate', 'accumulation', 'accuracy',
#        'accurate', 'accurately', 'accurateness', 'accused', 'accustomed',
#        'ace'], dtype=object)

# %%
tokens[-100:]
# Out:
# array(['workshop', 'world', 'worm', 'worn', 'worry', 'worsening',
#        'worship', 'worst', 'worth', 'worthiness', 'worthy', 'would',
#        'wound', 'wounded', 'woven', 'wow', 'wowt', 'wrangler', 'wrap',
#        'wrapped', 'wrapper', 'wrapping', 'wren', 'wrench', 'wrestler',
#        'wrestling', 'wright', 'wrinkle', 'wrist', 'wristband', 'writ',
#        'write', 'writer', 'writing', 'written', 'wrong', 'wrongful',
#        'wrote', 'wrought', 'wy', 'wynn', 'xerostomia', 'xi', 'ya',
#        'yacht', 'yachting', 'yahoo', 'yale', 'yam', 'yammer', 'yang',
#        'yard', 'yarn', 'yaw', 'yea', 'year', 'yearbook', 'yearlong',
#        'yearly', 'yeast', 'yellow', 'yelp', 'yeni', 'yes', 'yet', 'yield',
#        'yielding', 'ym', 'yo', 'yoga', 'yoke', 'york', 'yorker', 'young',
#        'younger', 'youth', 'youthful', 'yoy', 'yr', 'yucca', 'zar',
#        'zeal', 'zealous', 'zed', 'zenith', 'zero', 'zeta', 'zigzag',
#        'zimbabwe', 'zinc', 'zip', 'zipper', 'zodiac', 'zombie', 'zonal',
#        'zone', 'zoned', 'zoning', 'zoo', 'zoom'], dtype=object)

# %%
tfidf_transformer = TfidfTransformer()

# %%
X_train_tfidf = tfidf_transformer.fit_transform(conuntvectorizer_train)
X_test_tfidf = tfidf_transformer.fit_transform(conuntvectorizer_test)

# %% [markdown]
# # using grid search for find optimal values for RF classifier
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import GridSearchCV
#
# RFC = RandomForestClassifier(random_state=42)
#
# param_grid = {
#     'n_estimators': [200, 500],
#     'max_features': ['auto', 'sqrt', 'log2'],
#     'max_depth' : [4,5,6,7,8],
#     'criterion' :['gini', 'entropy']
# }
#
# grid = GridSearchCV(estimator=RFC, param_grid=param_grid, cv= 5, scoring='accuracy', return_train_score=False, verbose=1)
# grid_search = grid.fit(X_train_tfidf, y_train)
#
# print(grid_search.best_params_)

# %%
from sklearn.ensemble import RandomForestClassifier

RF_Model = RandomForestClassifier(random_state=42, max_features='sqrt', n_estimators= 500, max_depth=8, criterion='gini')
RF_Model.fit(X_train_tfidf, y_train)
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=500, random_state=42)

# %%
prediction=RF_Model.predict(X_test_tfidf)
prediction
# Out:
# array(['DESIGNER', 'PUBLIC-RELATIONS', 'CHEF', 'HEALTHCARE',
#        'CONSTRUCTION', 'HR', 'HEALTHCARE', 'PUBLIC-RELATIONS',
#        'CONSULTANT', 'DIGITAL-MEDIA', 'DIGITAL-MEDIA', 'HR', 'HEALTHCARE',
#        'ADVOCATE', 'ENGINEERING', 'CONSTRUCTION', 'AVIATION',
#        'ACCOUNTANT', 'INFORMATION-TECHNOLOGY', 'CONSTRUCTION', 'TEACHER',
#        'PUBLIC-RELATIONS', 'HR', 'BUSINESS-DEVELOPMENT', 'ACCOUNTANT',
#        'FINANCE', 'BUSINESS-DEVELOPMENT', 'FINANCE', 'ADVOCATE',
#        'PUBLIC-RELATIONS', 'INFORMATION-TECHNOLOGY', 'FITNESS',
#        'DIGITAL-MEDIA', 'CHEF', 'ACCOUNTANT', 'DESIGNER', 'TEACHER',
#        'PUBLIC-RELATIONS', 'ENGINEERING', 'SALES', 'CONSTRUCTION',
#        'FITNESS', 'DESIGNER', 'BUSINESS-DEVELOPMENT', 'TEACHER',
#        'INFORMATION-TECHNOLOGY', 'PUBLIC-RELATIONS', 'ADVOCATE',
#        'ACCOUNTANT', 'CONSTRUCTION', 'DESIGNER', 'FINANCE', 'ADVOCATE',
#        'ACCOUNTANT', 'INFORMATION-TECHNOLOGY', 'ACCOUNTANT', 'SALES',
#        'BUSINESS-DEVELOPMENT', 'BANKING', 'INFORMATION-TECHNOLOGY',
#        'CONSTRUCTION', 'BANKING', 'CONSULTANT', 'ACCOUNTANT',
#        'BUSINESS-DEVELOPMENT', 'CHEF', 'CONSTRUCTION', 'AVIATION',
#        'FITNESS', 'PUBLIC-RELATIONS', 'BUSINESS-DEVELOPMENT',
#        'INFORMATION-TECHNOLOGY', 'INFORMATION-TECHNOLOGY', 'HR',
#        'APPAREL', 'BANKING', 'HR', 'HEALTHCARE', 'CHEF', 'SALES',
#        'INFORMATION-TECHNOLOGY', 'ACCOUNTANT', 'INFORMATION-TECHNOLOGY',
#        'BUSINESS-DEVELOPMENT', 'SALES', 'DIGITAL-MEDIA', 'DESIGNER', 'HR',
#        'HR', 'DESIGNER', 'ACCOUNTANT', 'FITNESS', 'ENGINEERING',
#        'PUBLIC-RELATIONS', 'ENGINEERING', 'CHEF', 'DESIGNER', 'TEACHER',
#        'HEALTHCARE', 'AVIATION', 'PUBLIC-RELATIONS', 'TEACHER',
#        'CONSTRUCTION', 'AVIATION', 'ACCOUNTANT', 'CHEF', 'ACCOUNTANT',
#        'TEACHER', 'TEACHER', 'ACCOUNTANT', 'HR', 'BUSINESS-DEVELOPMENT',
#        'INFORMATION-TECHNOLOGY', 'PUBLIC-RELATIONS',
#        'BUSINESS-DEVELOPMENT', 'HR', 'CHEF', 'FITNESS', 'HEALTHCARE',
#        'ACCOUNTANT', 'DESIGNER', 'ADVOCATE', 'CONSULTANT', 'FITNESS',
#        'CHEF', 'HR', 'PUBLIC-RELATIONS', 'DIGITAL-MEDIA', 'HR', 'SALES',
#        'CHEF', 'HEALTHCARE', 'TEACHER', 'HEALTHCARE', 'SALES', 'SALES',
#        'ACCOUNTANT', 'DESIGNER', 'FINANCE', 'AVIATION', 'HEALTHCARE',
#        'CONSULTANT', 'BUSINESS-DEVELOPMENT', 'ACCOUNTANT', 'CONSTRUCTION',
#        'HR', 'SALES', 'CONSTRUCTION', 'INFORMATION-TECHNOLOGY', 'APPAREL',
#        'BUSINESS-DEVELOPMENT', 'PUBLIC-RELATIONS', 'ENGINEERING',
#        'PUBLIC-RELATIONS', 'PUBLIC-RELATIONS', 'BUSINESS-DEVELOPMENT',
#        'TEACHER', 'BANKING', 'INFORMATION-TECHNOLOGY', 'HR',
#        'BUSINESS-DEVELOPMENT', 'INFORMATION-TECHNOLOGY', 'ENGINEERING',
#        'INFORMATION-TECHNOLOGY', 'INFORMATION-TECHNOLOGY', 'HEALTHCARE',
#        'PUBLIC-RELATIONS', 'ENGINEERING', 'ACCOUNTANT', 'FINANCE', 'CHEF',
#        'CONSULTANT', 'CONSULTANT', 'CHEF', 'SALES',
#        'INFORMATION-TECHNOLOGY', 'ACCOUNTANT', 'HEALTHCARE', 'DESIGNER',
#        'DIGITAL-MEDIA', 'CONSTRUCTION', 'FITNESS', 'HEALTHCARE',
#        'PUBLIC-RELATIONS', 'AVIATION', 'INFORMATION-TECHNOLOGY', 'HR',
#        'HR', 'ACCOUNTANT', 'ACCOUNTANT', 'PUBLIC-RELATIONS', 'TEACHER',
#        'ACCOUNTANT', 'CHEF', 'CHEF', 'FITNESS', 'BUSINESS-DEVELOPMENT',
#        'CONSTRUCTION', 'HR', 'TEACHER', 'HR', 'HR', 'AVIATION',
#        'ENGINEERING', 'ACCOUNTANT', 'CONSTRUCTION',
#        'BUSINESS-DEVELOPMENT', 'BUSINESS-DEVELOPMENT', 'TEACHER',
#        'ACCOUNTANT', 'INFORMATION-TECHNOLOGY', 'ACCOUNTANT', 'CHEF',
#        'ENGINEERING', 'ADVOCATE', 'CHEF', 'CONSTRUCTION', 'TEACHER',
#        'FITNESS', 'DESIGNER', 'HR', 'CONSULTANT', 'DESIGNER',
#        'HEALTHCARE', 'TEACHER', 'TEACHER', 'CHEF',
#        'INFORMATION-TECHNOLOGY', 'PUBLIC-RELATIONS',
#        'INFORMATION-TECHNOLOGY', 'DESIGNER', 'INFORMATION-TECHNOLOGY',
#        'INFORMATION-TECHNOLOGY', 'CONSTRUCTION', 'AVIATION',
#        'INFORMATION-TECHNOLOGY', 'SALES', 'ACCOUNTANT',
#        'INFORMATION-TECHNOLOGY', 'DESIGNER', 'AVIATION', 'FITNESS',
#        'HEALTHCARE', 'SALES', 'INFORMATION-TECHNOLOGY', 'SALES',
#        'CONSTRUCTION', 'BUSINESS-DEVELOPMENT', 'BUSINESS-DEVELOPMENT',
#        'DESIGNER', 'CONSTRUCTION', 'ENGINEERING', 'AVIATION', 'TEACHER',
#        'BUSINESS-DEVELOPMENT', 'ENGINEERING', 'ADVOCATE', 'TEACHER',
#        'TEACHER', 'PUBLIC-RELATIONS', 'DESIGNER', 'TEACHER', 'SALES',
#        'CONSTRUCTION', 'ACCOUNTANT', 'ADVOCATE', 'AVIATION',
#        'BUSINESS-DEVELOPMENT', 'AVIATION', 'AVIATION', 'CONSTRUCTION',
#        'BUSINESS-DEVELOPMENT', 'BUSINESS-DEVELOPMENT', 'CHEF', 'HR',
#        'SALES', 'DESIGNER', 'BANKING', 'CHEF', 'FINANCE', 'BANKING',
#        'BUSINESS-DEVELOPMENT', 'AVIATION', 'ADVOCATE', 'FINANCE',
#        'BUSINESS-DEVELOPMENT', 'DESIGNER', 'PUBLIC-RELATIONS',
#        'BUSINESS-DEVELOPMENT', 'CHEF', 'PUBLIC-RELATIONS',
#        'PUBLIC-RELATIONS', 'TEACHER', 'FINANCE', 'AVIATION', 'TEACHER',
#        'BUSINESS-DEVELOPMENT', 'ENGINEERING', 'BANKING', 'FINANCE',
#        'AVIATION', 'ADVOCATE', 'ACCOUNTANT', 'DESIGNER',
#        'BUSINESS-DEVELOPMENT', 'ADVOCATE', 'BUSINESS-DEVELOPMENT',
#        'ACCOUNTANT', 'BUSINESS-DEVELOPMENT', 'CONSULTANT', 'HEALTHCARE',
#        'ENGINEERING', 'ADVOCATE', 'FINANCE', 'HR', 'ACCOUNTANT',
#        'ENGINEERING', 'FINANCE', 'DESIGNER', 'APPAREL', 'ACCOUNTANT',
#        'BUSINESS-DEVELOPMENT', 'AVIATION', 'ADVOCATE', 'HR', 'FINANCE',
#        'CONSULTANT', 'HR', 'CHEF', 'INFORMATION-TECHNOLOGY', 'TEACHER',
#        'FITNESS', 'HEALTHCARE', 'ACCOUNTANT', 'ACCOUNTANT', 'CHEF',
#        'ACCOUNTANT', 'HR', 'BUSINESS-DEVELOPMENT', 'HR', 'APPAREL',
#        'BANKING', 'HEALTHCARE', 'BANKING', 'AVIATION', 'PUBLIC-RELATIONS',
#        'ADVOCATE', 'HEALTHCARE', 'BUSINESS-DEVELOPMENT', 'AVIATION',
#        'ACCOUNTANT', 'ADVOCATE', 'INFORMATION-TECHNOLOGY', 'CHEF',
#        'BUSINESS-DEVELOPMENT', 'ENGINEERING', 'HR', 'AVIATION',
#        'CONSULTANT', 'AVIATION', 'CONSTRUCTION', 'DIGITAL-MEDIA', 'SALES',
#        'HR', 'TEACHER', 'SALES', 'ENGINEERING', 'BANKING', 'FITNESS',
#        'SALES', 'BUSINESS-DEVELOPMENT', 'ADVOCATE', 'AVIATION', 'HR',
#        'ADVOCATE', 'BUSINESS-DEVELOPMENT', 'BANKING', 'PUBLIC-RELATIONS',
#        'HEALTHCARE', 'TEACHER', 'INFORMATION-TECHNOLOGY', 'SALES',
#        'ENGINEERING', 'APPAREL', 'HEALTHCARE', 'DESIGNER', 'AVIATION',
#        'SALES', 'ADVOCATE', 'ADVOCATE', 'INFORMATION-TECHNOLOGY',
#        'ACCOUNTANT', 'TEACHER', 'ACCOUNTANT', 'CONSTRUCTION', 'TEACHER',
#        'TEACHER', 'ACCOUNTANT', 'TEACHER', 'INFORMATION-TECHNOLOGY',
#        'FITNESS', 'ACCOUNTANT', 'AVIATION', 'ADVOCATE', 'HR', 'FITNESS',
#        'HEALTHCARE', 'SALES', 'ENGINEERING', 'PUBLIC-RELATIONS',
#        'INFORMATION-TECHNOLOGY', 'INFORMATION-TECHNOLOGY', 'FITNESS',
#        'ENGINEERING', 'HEALTHCARE', 'FINANCE', 'PUBLIC-RELATIONS',
#        'INFORMATION-TECHNOLOGY', 'ACCOUNTANT', 'ACCOUNTANT',
#        'INFORMATION-TECHNOLOGY', 'ENGINEERING', 'DIGITAL-MEDIA',
#        'BANKING', 'CHEF', 'PUBLIC-RELATIONS', 'SALES', 'DIGITAL-MEDIA',
#        'TEACHER', 'INFORMATION-TECHNOLOGY', 'CONSTRUCTION', 'AVIATION',
#        'TEACHER', 'ACCOUNTANT', 'FITNESS', 'CHEF', 'BANKING',
#        'INFORMATION-TECHNOLOGY', 'TEACHER', 'ADVOCATE', 'FINANCE',
#        'HEALTHCARE', 'AVIATION', 'INFORMATION-TECHNOLOGY',
#        'INFORMATION-TECHNOLOGY', 'ACCOUNTANT', 'ENGINEERING', 'AVIATION',
#        'CHEF', 'ACCOUNTANT', 'TEACHER', 'ENGINEERING', 'TEACHER',
#        'AGRICULTURE', 'BANKING', 'CONSTRUCTION', 'CONSTRUCTION',
#        'DESIGNER', 'TEACHER', 'CHEF', 'CHEF', 'BANKING', 'FITNESS',
#        'FINANCE', 'ACCOUNTANT', 'ACCOUNTANT', 'TEACHER',
#        'PUBLIC-RELATIONS', 'TEACHER', 'TEACHER', 'DIGITAL-MEDIA',
#        'AVIATION', 'INFORMATION-TECHNOLOGY', 'PUBLIC-RELATIONS', 'HR',
#        'CHEF', 'ENGINEERING', 'TEACHER', 'HEALTHCARE', 'PUBLIC-RELATIONS',
#        'DESIGNER', 'FITNESS', 'CHEF', 'CONSTRUCTION', 'FINANCE',
#        'PUBLIC-RELATIONS', 'ADVOCATE', 'BUSINESS-DEVELOPMENT', 'FITNESS',
#        'DIGITAL-MEDIA', 'PUBLIC-RELATIONS', 'CHEF', 'ENGINEERING',
#        'FITNESS', 'BANKING', 'HR', 'APPAREL'], dtype=object)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,prediction, zero_division=0))        #TODO TOGLIERE zero_division=0
# Out:
#                         precision    recall  f1-score   support
#
#             ACCOUNTANT       0.52      0.96      0.68        24
#               ADVOCATE       0.82      0.75      0.78        24
#            AGRICULTURE       1.00      0.08      0.14        13
#                APPAREL       1.00      0.32      0.48        19
#                   ARTS       0.00      0.00      0.00        21
#             AUTOMOBILE       0.00      0.00      0.00         7
#               AVIATION       0.71      0.83      0.77        24
#                BANKING       0.81      0.57      0.67        23
#                    BPO       0.00      0.00      0.00         4
#   BUSINESS-DEVELOPMENT       0.44      0.67      0.53        24
#                   CHEF       0.70      0.88      0.78        24
#           CONSTRUCTION       0.80      0.91      0.85        22
#             CONSULTANT       0.60      0.26      0.36        23
#               DESIGNER       0.83      0.90      0.86        21
#          DIGITAL-MEDIA       0.82      0.47      0.60        19
#            ENGINEERING       0.75      0.75      0.75        24
#                FINANCE       0.69      0.46      0.55        24
#                FITNESS       0.75      0.65      0.70        23
#             HEALTHCARE       0.50      0.52      0.51        23
#                     HR       0.65      0.91      0.75        22
# INFORMATION-TECHNOLOGY       0.59      0.96      0.73        24
#       PUBLIC-RELATIONS       0.50      0.73      0.59        22
#                  SALES       0.43      0.39      0.41        23
#                TEACHER       0.53      1.00      0.69        20
#
#               accuracy                           0.64       497
#              macro avg       0.60      0.58      0.55       497
#           weighted avg       0.63      0.64      0.60       497

# %%
print("training Score: {:.2f}".format(RF_Model.score(X_train_tfidf, y_train)))
print("test Score: {:.2f}".format(RF_Model.score(X_test_tfidf, y_test)))
# Out:
# training Score: 0.89
# test Score: 0.64

# %%
from sklearn.metrics import ConfusionMatrixDisplay
plt.figure(figsize=(15, 10))  # Imposta la dimensione della figura
ConfusionMatrixDisplay.from_predictions(y_test, prediction)
plt.xticks(rotation=90)
plt.show()

# %%
y_test.value_counts().sort_index().plot(kind='bar', title='Classes distribution', figsize=(10,6))
plt.show()
